# %% [markdown]
# # 3월 27일

# %% [markdown]
# ## 오전

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\pandas'

# %% [markdown]
# - scientits.csv 파일 읽기 > tab을 이용하여 파일 읽기를 해야 오류가 안남

# %%
df = pd.read_csv("./data/scientists.csv")
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
# 데이터의 마지막 3행만 출력

print(df.tail(3))

# or

print(df.iloc[-3: , : ])
# Out:
#            Name        Born        Died  Age          Occupation
# 5     John Snow  1813-03-15  1858-06-16   45           Physician
# 6   Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7  Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#            Name        Born        Died  Age          Occupation
# 5     John Snow  1813-03-15  1858-06-16   45           Physician
# 6   Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7  Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
# Age 열과 Occupation 열만 따로 추출

print(df.iloc[  : , -2 : ] )
print(df.iloc[  : , [3,4] ] )
print(df.loc[  : , ['Age' , 'Occupation'] ] )
print(df[['Age' , 'Occupation'] ] )
# Out:
#    Age          Occupation
# 0   37             Chemist
# 1   61        Statistician
# 2   90               Nurse
# 3   66             Chemist
# 4   56           Biologist
# 5   45           Physician
# 6   41  Computer Scientist
# 7   77       Mathematician
#    Age          Occupation
# 0   37             Chemist
# 1   61        Statistician
# 2   90               Nurse
# 3   66             Chemist
# 4   56           Biologist
# 5   45           Physician
# 6   41  Computer Scientist
# 7   77       Mathematician
#    Age          Occupation
# 0   37             Chemist
# 1   61        Statistician
# 2   90               Nurse
# 3   66             Chemist
# 4   56           Biologist
# 5   45           Physician
# 6   41  Computer Scientist
# 7   77       Mathematician
#    Age          Occupation
# 0   37             Chemist
# 1   61        Statistician
# 2   90               Nurse
# 3   66             Chemist
# 4   56           Biologist
# 5   45           Physician
# ...

# %%
# 인덱스가 3인 행의 Name을 추출

print(df.loc[3, 'Name'])
# Out:
# Marie Curie

# %%
# iloc를 사용하여 첫번째 행부터 다섯번째 행까지, 그리고 첫번째열부터 세번째 열까지 추출

print(df.iloc[ : 5, : 3])
# Out:
#                    Name        Born        Died
# 0     Rosaline Franklin  1920-07-25  1958-04-16
# 1        William Gosset  1876-06-13  1937-10-16
# 2  Florence Nightingale  1820-05-12  1910-08-13
# 3           Marie Curie  1867-11-07  1934-07-04
# 4         Rachel Carson  1907-05-27  1964-04-14

# %% [markdown]
# ```
# 판다스 라이브러리를 사용하여 다음 Series를 생성하는 코드를 작성하세요.
#
# 0      10
# 1      20
# 2      30
# 3      40
# dtype: int64

# %%
pd.Series([10, 20, 30, 40]) # 시리즈는 판다스에서 말하는 리스트다.
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([10, 20, 30, 40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
print(s[1])
print(s[1:3])
# Out:
# 20
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# - tsv 파일 읽기

# %%
# ' gapminder.tsv' 를 읽어주세요.

gap = pd.read_csv("data/gapminder.tsv", sep='\t')
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# 끝에 열개

gap.tail(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# 위에 세개만 보기

gap.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %% [markdown]
# - 데이터 프레임 만들기
#
# ```
#    이름   나이   점수
# 0  현수    20    85
# 1  영희    22    90
# 2  민수    21    78
# ```

# %%
# 만들기 

people = pd.DataFrame({
    "Name": ['현수', '영희', '민수'],
    "Age": [20, 22, 21],
    "Score": [85, 90, 78]}, index = ['이름', '나이', '점수'])

print(people)
# Out:
#    Name  Age  Score
# 이름   현수   20     85
# 나이   영희   22     90
# 점수   민수   21     78

# %%
pd.DataFrame([['현수', 20, 85], ['영희', 22, 90], ['민수', 21, 78]],
             columns = ['이름', '나이', '점수'])
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90
# 2  민수  21  78

# %%
pd.DataFrame({'이름': ['현수', '영희', '민수'] , '나이': [20, 22, 21], '점수' : [85, 90, 78]})
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90
# 2  민수  21  78

# %% [markdown]
# ## 오후

# %%
df = pd.DataFrame([['현수', 20, 85], ['영희', 22, 90], ['민수', 21, 78]],
             columns = ['이름', '나이', '점수'])
df
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90
# 2  민수  21  78

# %%
# 점수열 만 출력 - 시리즈 보기

df.iloc[:, -1]
df.iloc[:, 2]
df.loc[:, '점수']
df["점수"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: 점수, dtype: int64

# %%
# 점수열 만 출력 - 데이터 프레임 보기 - 묶어주면 아래 처럼 볼 수 있다.

df.iloc[:, [-1]]
df.iloc[:, [2]]
df.loc[:, ['점수']]
df[["점수"]]
# Out:
#    점수
# 0  85
# 1  90
# 2  78

# %%
# 나이, 점수열 만 출력

df.iloc[:, [1, 2]]
df.loc[:, ['나이', '점수']]
df[["나이", "점수"]]
# Out:
#    나이  점수
# 0  20  85
# 1  22  90
# 2  21  78

# %%
# 영희의 점수를 출력
df = pd.DataFrame([['현수', 20, 85], ['영희', 22, 90], ['민수', 21, 78]],
             columns = ['이름', '나이', '점수'])

df.loc[1, "점수"]
df.iloc[[1], [2]]
# Out:
#    점수
# 1  90

# %%
df['점수'][1]
# Out:
# np.int64(90)

# %%
df[1:2]['점수']
# Out:
# 1    90
# Name: 점수, dtype: int64

# %%
# 철수의 전화번호를 출력해주세요

friends = {"철수": ["010-1234-5678"], "영희": ["010-9876-5432"]}
friends["철수"] # 접근할 때는 대괄호 []로 접근
# Out:
# ['010-1234-5678']

# %%
# 위 딕셔너리를 데이터 프레임으로 만들고 index를 전화번호로 합니다.

pd.DataFrame(friends, index = ["전화번호"])

# 딕셔너리를 데이터 프레임으로 만들 때는 value 를 [] 대괄호로 묶어줘야 함!
# Out:
#                  철수             영희
# 전화번호  010-1234-5678  010-9876-5432

# %% [markdown]
# # 3월 31일

# %% [markdown]
# ## 오전

# %%
# 표를 작성하시오. 

import pandas as pd

df = pd.DataFrame({"K" : [23, 11], "D" : [11, 23], "A" : [56, 25]}, index = ['T1', 'KT'])
df = pd.DataFrame([[23, 11, 56], [11, 23, 25]], index = ['T1', 'KT'], columns = ['K', 'D', 'A'])
df
# Out:
#      K   D   A
# T1  23  11  56
# KT  11  23  25

# %%
df['결과'] = ['우승', '준우승']
df
# Out:
#      K   D   A   결과
# T1  23  11  56   우승
# KT  11  23  25  준우승

# %%
# KDA 총합 칼럼을 마지막에 추가

df['총합'] = df["K"] + df["D"] + df["A"]
df
# Out:
#      K   D   A   결과  총합
# T1  23  11  56   우승  90
# KT  11  23  25  준우승  59

# %%
df['총합'] = df.iloc[:, :3].sum(axis=1)
df
# Out:
#      K   D   A   결과  총합
# T1  23  11  56   우승  90
# KT  11  23  25  준우승  59

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\pandas'

# %%
# wine.csv 열어보세요.


df = pd.read_csv('./data/wine.csv')
df
# Out:
#      Cultivar  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0           1    14.23        1.71  2.43                 15.6        127
# 1           1    13.20        1.78  2.14                 11.2        100
# 2           1    13.16        2.36  2.67                 18.6        101
# 3           1    14.37        1.95  2.50                 16.8        113
# 4           1    13.24        2.59  2.87                 21.0        118
# ..        ...      ...         ...   ...                  ...        ...
# 173         3    13.71        5.65  2.45                 20.5         95
# 174         3    13.40        3.91  2.48                 23.0        102
# 175         3    13.27        4.28  2.26                 20.0        120
# 176         3    13.17        2.59  2.37                 20.0        120
# 177         3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
# Ash 2번을 5.0 으로 바꾸어라.

df.iloc[2,3]= 5.0
df
# Out:
#      Cultivar  Alcohol  Malic acid   Ash  Alcalinity of ash    Magnesium  \
# 0           1    14.23        1.71  2.43                 15.6        127
# 1           1    13.20        1.78  2.14                 11.2        100
# 2           1    13.16        2.36  5.00                 18.6        101
# 3           1    14.37        1.95  2.50                 16.8        113
# 4           1    13.24        2.59  2.87                 21.0        118
# ..        ...      ...         ...   ...                  ...        ...
# 173         3    13.71        5.65  2.45                 20.5         95
# 174         3    13.40        3.91  2.48                 23.0        102
# 175         3    13.27        4.28  2.26                 20.0        120
# 176         3    13.17        2.59  2.37                 20.0        120
# 177         3    14.13        4.10  2.74                 24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %% [markdown]
# ## 오후

# %%
df = pd.DataFrame([
    ['현수', 20, 85],
    ['영희', 22, 90],
    ['민수', 21, 78]
], columns=['이름', '나이', '점수'])

df
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90
# 2  민수  21  78

# %%
# "점수" 열만 출력

# 시리즈로 출력
df.iloc[:, 2]
df.iloc[:, -1]
df.loc[:, '점수']

# 데이터프레임으로 출력
df.iloc[:, [2]]
df['점수']
df[['점수']]

df.점수                   # 비권장 / 열이 한개일때만 가능
# Out:
# 0    85
# 1    90
# 2    78
# Name: 점수, dtype: int64

# %%
# 나이열의 평균

df['나이'].mean()
# Out:
# np.float64(21.0)

# %%
# 점수가 평균보다 높은 학생만 출력
# [df['점수'] > df['점수'].mean()] 이렇게만 입력하면 true false 로 나옴.

df[df['점수'] > df['점수'].mean()]
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90

# %%
# 점수가 평균보다 높고 나이가 21 이상인 학생을 출력하세요
# 방법 1

df[(df['점수'] > df['점수'].mean()) & (df['나이'] > 21)]
# Out:
#    이름  나이  점수
# 1  영희  22  90

# %%
# 방법 2

cond1 = df['점수'] > df['점수'].mean()
cond2 = df['나이'] > 21

df[cond1 & cond2]
# Out:
#    이름  나이  점수
# 1  영희  22  90

# %%
# 방법 3

df.query('점수 > 점수.mean() and 나이 > 21')    # query 에 글자가 들어오면 칼럼으로 인식함.
# Out:
#    이름  나이  점수
# 1  영희  22  90

# %%
# columns 를 다음과 같이 수정

df.columns = ['Name', 'Age', 'Score']
df
# Out:
#   Name  Age  Score
# 0   현수   20     85
# 1   영희   22     90
# 2   민수   21     78

# %%
# df[Age] 와 df[0:3] 각각 비교하고 차이점을 설명하라.

df['Age']      # 열 추출

df[0:3]        # 행 추출
# Out:
#   Name  Age  Score
# 0   현수   20     85
# 1   영희   22     90
# 2   민수   21     78

# %%
pop = pd.DataFrame({
    "서울": [200, 220, 210, 180],
    "인천": [80, 90, 85, 70],
    "대전": [60, 65, 62, 55],
    "부산": [120, 130, 125, 110]
},  index = ["60대", "50대", "40대", "30대"])


# 총합 열 추가

pop['총합'] = pop.sum(axis = 1)

# 다른 방법

pop['총합'] = pop['서울'] + pop['인천'] + pop['대전'] + pop['부산']

# 다른 방법
# pop['총합'] = pop.apply(np.sum, axis = 1)


# 지우기 1 pop = pop.iloc[:, :-1]
# 지우기 2 pop.drop("총합", axis = 1, inplace = True)

# %% [markdown]
# # 4월 1일

# %% [markdown]
# ## 오전

# %%
# anscom 

import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset("anscombe")
data
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# dataset1을 피클로 저장하기 

data.to_pickle("datase1.pickle")

# %%
# 피클로 저장한 dataset1 를 읽어오기

pd.read_pickle("dataset1.pickle")
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import pickle

# %%
# with open 사용하여 피클로 저장하기

with open("dataset2.pickle", 'wb') as f:
    pickle.dump(data, f)

# %%
with open ('dataset2.pickle', 'rb') as f:
    dataset1 = pickle.load(f)

# %%
# dataset1.pickle 파일을 읽어서 x+y '합' 컬럼 추가

data['총합'] = data['x'] + data['y']
data
# Out:
#    dataset     x      y     총합
# 0        I  10.0   8.04  18.04
# 1        I   8.0   6.95  14.95
# 2        I  13.0   7.58  20.58
# 3        I   9.0   8.81  17.81
# 4        I  11.0   8.33  19.33
# 5        I  14.0   9.96  23.96
# 6        I   6.0   7.24  13.24
# 7        I   4.0   4.26   8.26
# 8        I  12.0  10.84  22.84
# 9        I   7.0   4.82  11.82
# 10       I   5.0   5.68  10.68
# 11      II  10.0   9.14  19.14
# 12      II   8.0   8.14  16.14
# 13      II  13.0   8.74  21.74
# 14      II   9.0   8.77  17.77
# 15      II  11.0   9.26  20.26
# 16      II  14.0   8.10  22.10
# 17      II   6.0   6.13  12.13
# 18      II   4.0   3.10   7.10
# 19      II  12.0   9.13  21.13
# 20      II   7.0   7.26  14.26
# 21      II   5.0   4.74   9.74
# 22     III  10.0   7.46  17.46
# 23     III   8.0   6.77  14.77
# 24     III  13.0  12.74  25.74
# 25     III   9.0   7.11  16.11
# 26     III  11.0   7.81  18.81
# 27     III  14.0   8.84  22.84
# 28     III   6.0   6.08  12.08
# ...

# %%
# 다른 방법

# data = data.iloc[:, :-1]
# data[ ['x', 'y'] ]
# data['총합'] = data [ ['x', 'y'] ].apply(sum,axis = 1)

# %%
# x 축은 인덱스 y 측은 sum 바 그래프로

# %%
data[:2]
data1 = data.query( ' dataset == "I" ' )

# %%
data1.plot(kind = 'bar', y = '총합' )  # x 값은 디폴트로 인덱스를 잡는다.
# Out:
# <Axes: >

# %%
# matplotlib 이용하기

plt.bar(x = data1.index, height=data1['총합])
# Out:
#   Cell In[57], line 3
#     plt.bar(x = data1.index, height=data1['총합])
#                                           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# DataFrame 에서 plot(kind = 'bar')

data1.plot(kind = 'bar', x=  , y = '총합' )  # x 값은 디폴트로 인덱스를 잡는다.
# Out:
#   Cell In[58], line 3
#     data1.plot(kind = 'bar', x=  , y = '총합' )  # x 값은 디폴트로 인덱스를 잡는다.
#                              ^
# SyntaxError: expected argument value expression

# %%
data.columns # 칼럼만 나옴
data.index # 인덱스만 나옴

# %%
# 폰트 설정 코드 추가 > 한글을 못 읽을 때.

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ## 오후

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
"Date": pd.to_datetime(["2026-01-15","2026-02-15","2026-03-15"]),
"Gold_Price_USD": [5594, 5100, 5000]
})

# %%
plt.plot(df["Date"], df["Gold_Price_USD"], marker='o', color='red')
plt.title("Gold Price Trend")
plt.xlabel("Date")
plt.ylabel("Price (USD/oz)")
plt.grid(True)
plt.xticks(rotation=45)
# Out:
# (array([20468., 20475., 20485., 20492., 20499., 20506., 20513., 20520.,
#         20527.]),
#  [Text(20468.0, 0, '2026-01-15'),
#   Text(20475.0, 0, '2026-01-22'),
#   Text(20485.0, 0, '2026-02-01'),
#   Text(20492.0, 0, '2026-02-08'),
#   Text(20499.0, 0, '2026-02-15'),
#   Text(20506.0, 0, '2026-02-22'),
#   Text(20513.0, 0, '2026-03-01'),
#   Text(20520.0, 0, '2026-03-08'),
#   Text(20527.0, 0, '2026-03-15')])

# %%
df = pd.DataFrame({
    "날짜": ["2026-03-28", "2026-03-29", "2026-03-30", "2026-03-31"],
    "기온": [18, 20, 19, 21],
    "강수량": [5, 0, 10, 2],
    "습도": [60, 55, 65, 50]})

df
# Out:
#            날짜  기온  강수량  습도
# 0  2026-03-28  18    5  60
# 1  2026-03-29  20    0  55
# 2  2026-03-30  19   10  65
# 3  2026-03-31  21    2  50

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      4 non-null      str
#  1   기온      4 non-null      int64
#  2   강수량     4 non-null      int64
#  3   습도      4 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 260.0 bytes

# %%
# 날짜의 type 을 datetime 으로 바꿔주랍

# df['날짜'].astype("datetime64[ns]")

df['날짜'] = pd.to_datetime(df['날짜'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      4 non-null      datetime64[us]
#  1   기온      4 non-null      int64
#  2   강수량     4 non-null      int64
#  3   습도      4 non-null      int64
# dtypes: datetime64[us](1), int64(3)
# memory usage: 260.0 bytes

# %%
# 날짜와 기온 을 사용하여 그래프를 그려라 

plt.plot(df["날짜"], df["기온"])
plt.title("기온그래프")
plt.xlabel("날짜")
plt.ylabel("기온")
# Out:
# Text(0, 0.5, '기온')

# %%
# 날짜를 인덱스로 바꾸는 .. 이런식으로도 생각해볼수있다.

df1 = df.set_index('날짜')
df1
# Out:
#             기온  강수량  습도
# 날짜
# 2026-03-28  18    5  60
# 2026-03-29  20    0  55
# 2026-03-30  19   10  65
# 2026-03-31  21    2  50

# %%
df1.plot(y = "기온")
plt.title("강수량그래프")
plt.xlabel("날짜")
plt.ylabel("강수량")
# Out:
# Text(0, 0.5, '강수량')

# %%
# 강수량 그래프를 그려라 

plt.plot(df["날짜"], df["강수량"])
plt.title("강수량그래프")
plt.xlabel("날짜")
plt.ylabel("강수량")
# Out:
# Text(0, 0.5, '강수량')

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
df1 = df.set_index('날짜')

df1.plot(y = "강수량", kind='bar')
plt.title("강수량그래프")
plt.xlabel("날짜")
plt.ylabel("강수량")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 3
#       1 df1 = df.set_index('날짜')
# ----> 3 df1.plot(y = "강수량", kind='bar')
#       4 plt.title("강수량그래프")
#       5 plt.xlabel("날짜")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#
# ...

# %% [markdown]
# # 4월 2일

# %% [markdown]
# ## 오전

# %%
import pandas as pd

# %%
gpu = pd.DataFrame(
    {'제조사':['NVIDIA','NVIDIA','NVIDIA','AMD','AMD','AMD'],
     '모델명':['RTX4060','RTX3060','RTX5070','Radeon Graphics','RX6700XT','RX7800XT'],
     '점유율':[4.36,4.28,2.87,2.27,1.14,1.11]})

gpu
# Out:
#       제조사              모델명   점유율
# 0  NVIDIA          RTX4060  4.36
# 1  NVIDIA          RTX3060  4.28
# 2  NVIDIA          RTX5070  2.87
# 3     AMD  Radeon Graphics  2.27
# 4     AMD         RX6700XT  1.14
# 5     AMD         RX7800XT  1.11

# %%
# 위 표에서 index 를 제조사로 바꾸시오

gpu = gpu.set_index("제조사")

# %%
gpu
# Out:
#                     모델명   점유율
# 제조사
# NVIDIA          RTX4060  4.36
# NVIDIA          RTX3060  4.28
# NVIDIA          RTX5070  2.87
# AMD     Radeon Graphics  2.27
# AMD            RX6700XT  1.14
# AMD            RX7800XT  1.11

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
import seaborn as sns

# %%
# 바 그래프로 만들기

gpu.plot(kind='bar', x='모델명', y='점유율', rot=0)
# Out:
# <Axes: xlabel='모델명'>

# %%
# 다른 방법 

sns.barplot(data=gpu, x='모델명', y='점유율')
plt.xticks(rotation=45)
plt.title("모델별 점유율")
plt.show()  # 그래프만 보고 싶을 때..

# %%
# 제조사가 엔비디아 인거 / amd 인거 두개의 데이터 프레임 만들기.

nvidia = gpu.query(' 제조사 == "NVIDIA" ')
amd = gpu.query(' 제조사 == "AMD" ')

# %%
sns.barplot(data=gpu, x='모델명', y='점유율')
plt.plot(nvidia['모델명'], nvidia['점유율'], 'go-')
plt.plot(amd['모델명'], amd['점유율'], 'ro-')
plt.xticks(rotation=45)
plt.title("모델별 점유율")
plt.show()

# %%
# 세계적으로 가장 많이쓰이는 ai 툴을 비교분석하자

for i in range(len(ai_tools)):
    plt.scatter(
        ai_tools[i],
        usage_mau[i],
        s=sizes[i],
        color=colors[i]
    )

plt.title("Global Usage of Major AI Tools")
plt.xlabel("AI Tool")
plt.ylabel("MAU (millions)")
plt.grid(axis='y', linestyle='--')

plt.show()

# %%
# 세계적으로 가장 많이쓰이는 ai 툴을 비교분석하자

ai_tools = ["ChatGPT", "Gemini", "Copilot", "Claude"]
usage_mau = [769, 29, 140, 5]
sizes = [u * 10 for u in usage_mau]
colors = ['blue', 'orange', 'green', 'red']


data = pd.DataFrame([ usage_mau, sizes, colors], columns=ai_tools)

# plt.figure(figsize=(8,4))

data
# Out:
#   ChatGPT  Gemini Copilot Claude
# 0     769      29     140      5
# 1    7690     290    1400     50
# 2    blue  orange   green    red

# %%
# 열을 행으로 바꾸기 - 트랜스포즈

data.T
# Out:
#            0     1       2
# ChatGPT  769  7690    blue
# Gemini    29   290  orange
# Copilot  140  1400   green
# Claude     5    50     red

# %%
df.columns = ['ori', "mau", 'color']
df
# Out:
#          ori   mau   color
# ChatGPT  769  7690    blue
# Gemini    29   290  orange
# Copilot  140  1400   green
# Claude     5    50     red

# %%
import seaborn as sns

sns.scatterplot(
    data=df,
    x=df.index,
    y='mau',
    size='mau',
    hue='color',
    legend=False)
# Out:
# <Axes: xlabel='None', ylabel='mau'>

# %%
plt.figure(figsize=(4,4))
plt.scatter(
        df.index,
        df['mau'],
        s =[769, 29, 140, 5],
        c = df['color']
    )
plt.title("Global Usage of Major AI Tools")
plt.xlabel("AI Tool")
plt.ylabel("MAU (millions)")
plt.grid(axis='y', linestyle='--')

# %% [markdown]
# # 4월 3일

# %% [markdown]
# ## 오전

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
data = {
    '요일': ['월', '화', '수', '목', '금', '토', '일'],
    '아메리카노': [50, 45, 60, 55, 80, 120, 110],
    '라떼': [40, 35, 50, 45, 70, 100, 90],
    '스무디': [20, 25, 30, 35, 50, 70, 65]
}

df = pd.DataFrame(data)
df
# Out:
#   요일  아메리카노   라떼  스무디
# 0  월     50   40   20
# 1  화     45   35   25
# 2  수     60   50   30
# 3  목     55   45   35
# 4  금     80   70   50
# 5  토    120  100   70
# 6  일    110   90   65

# %%
# 요일별 아메리카노 판매량을 sns.barplot() 로 시각화 하시오

sns.barplot(data=df, x='요일', y='아메리카노')
# sns.barplot(data=df, x='요일', y='아메리카노', hue= '요일', palette = 'Set3')
plt.title("요일별 아메리카노 판매량")
plt.show()

# %%
# 1) plt 를 사용하여 막대 그래프를 그려봅시다

# plt.bar(x = df['요일'], height = df['아메리카노'])
plt.bar(data = df, x = '요일', height = '아메리카노')
# Out:
# <BarContainer object of 7 artists>

# %%
# 2) df.plot() 으로 그려 봅시다.

df.plot(x = '요일', y = '아메리카노', kind = 'bar', rot=0)

## 색상은 cmap 을 이용 혹은 color = [리스트로 색상을 넣어 요일별로 다르게 가능]
# Out:
# <Axes: xlabel='요일'>

# %%
data = {
    '요일': ['월', '화', '수', '목', '금', '토', '일'],
    '아메리카노': [50, 45, 60, 55, 80, 120, 110],
    '라떼': [40, 35, 50, 45, 70, 100, 90],
    '스무디': [20, 25, 30, 35, 50, 70, 65]
}

df = pd.DataFrame(data)
df
# Out:
#   요일  아메리카노   라떼  스무디
# 0  월     50   40   20
# 1  화     45   35   25
# 2  수     60   50   30
# 3  목     55   45   35
# 4  금     80   70   50
# 5  토    120  100   70
# 6  일    110   90   65

# %%
# 요일별로 모든 음료의 평균 판매량을 구하고 시각화 하시오.

df['평균판매량'] = df[['아메리카노', '라떼', '스무디']].mean(axis=1)
df
# Out:
#   요일  아메리카노   라떼  스무디      평균판매량
# 0  월     50   40   20  36.666667
# 1  화     45   35   25  35.000000
# 2  수     60   50   30  46.666667
# 3  목     55   45   35  45.000000
# 4  금     80   70   50  66.666667
# 5  토    120  100   70  96.666667
# 6  일    110   90   65  88.333333

# %%
# 평균 구하기 다른 방법들

# # 방법 1
# df['평균판매량']= (df['아메리카노'] + df['라떼'] + df['스무디']) / 3
# df

# ---------------------------------------
# # 방법2
# # df = df.iloc[:, :-1]
# df['평균']= df.iloc[:, 1:].sum(axis=1)
# df

# ------------------------------------------
# # 방법3 
# df = df_origin.copy()
# # df['평균'] = df.iloc[:, 1: ].apply('mean', axis=1)
# # df['평균'] = df.iloc[:, 1: ].apply(np.mean, axis=1)
# # df['차이'] = df.iloc[:, 1: ].apply(test, axis=1)
# df['차이1'] = df.iloc[:, 1: ].apply(lambda x: x.max() - x.min(), axis=1)
# df

# # def test(x):
# #     return x.max() - x.min()


# >>  테스트를 쓰면 내가 만든 함수를 사용 할 수 있다.

# ----------------------------------
# # 방법 4
# df = df_origin.copy()
# # df = df.assign(평균= (df['아메리카노'] + df['라떼'] + df['스무디']) / 3 )
# # df = df.assign(평균= df.iloc[:, 1:].mean(axis=1) )
# df = df.assign(평균= df.iloc[:, 1: ].apply('mean', axis=1) )
# df

# %%
plt.bar(df['요일'], df['평균판매량'])
plt.title("요일별 음료 평균 판매량")
plt.show()

# %%
sns.barplot(data=df, x='요일',y=df.iloc[:,1:].mean(axis=1))
plt.ylabel('평균')
plt.title("요일별 음료 평균 판매량")
plt.show()

# %% [markdown]
# ## 오후

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

penguin = sns.load_dataset('penguins')
penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(data=penguin, x='island', y='bill_depth_mm', hue='species')
plt.style.use('default')
plt.show()

# %%
sns.scatterplot(data = penguin, x = 'flipper_length_mm', 
                y = 'body_mass_g', hue = 'island', s=25)

# s = 점(동그라미) 크기 - size 의 s
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.violinplot(data=penguin, x='species', y= 'flipper_length_mm', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

sns.violinplot(data=penguin, x='species', y= 'flipper_length_mm', hue='sex', ax=ax[0])
sns.scatterplot(data = penguin, x = 'flipper_length_mm', y = 'body_mass_g', hue = 'island', ax=ax[1])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# # 4월 6일

# %% [markdown]
# ## 오전

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1) 연도별로 pessengers 를 groupby 한다.
flights.groupby('year', as_index=False)[['passengers']].agg('mean')
# Out:
#     year  passengers
# 0   1949  126.666667
# 1   1950  139.666667
# 2   1951  170.166667
# 3   1952  197.000000
# 4   1953  225.000000
# 5   1954  238.916667
# 6   1955  284.000000
# 7   1956  328.250000
# 8   1957  368.416667
# 9   1958  381.000000
# 10  1959  428.333333
# 11  1960  476.166667

# %%
# 2) 라인플롯을 그린다.
sns.lineplot(data=flights, x="year", y="passengers", color="green", marker="o", errorbar=None)

plt.title('Monthly Flight Passengers (Yearly Average)')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
flights = sns.load_dataset('flights')

# 연도별로 'jul', 'Aug', 'Sep' 만 뽑아 주세요.
flights.query("month in ['Jul', 'Aug', 'Sep']")

# 이런 방법도 있다. > ("month == 'jul' or month == 'aug' or month == 'sep'")
# Out:
#      year month  passengers
# 6    1949   Jul         148
# 7    1949   Aug         148
# 8    1949   Sep         136
# 18   1950   Jul         170
# 19   1950   Aug         170
# 20   1950   Sep         158
# 30   1951   Jul         199
# 31   1951   Aug         199
# 32   1951   Sep         184
# 42   1952   Jul         230
# 43   1952   Aug         242
# 44   1952   Sep         209
# 54   1953   Jul         264
# 55   1953   Aug         272
# 56   1953   Sep         237
# 66   1954   Jul         302
# 67   1954   Aug         293
# 68   1954   Sep         259
# 78   1955   Jul         364
# 79   1955   Aug         347
# 80   1955   Sep         312
# 90   1956   Jul         413
# 91   1956   Aug         405
# 92   1956   Sep         355
# 102  1957   Jul         465
# 103  1957   Aug         467
# 104  1957   Sep         404
# 114  1958   Jul         491
# 115  1958   Aug         505
# 116  1958   Sep         404
# 126  1959   Jul         548
# 127  1959   Aug         559
# ...

# %%
# 2) 라인플롯을 그린다.
sns.lineplot(data=flights, x="year", y="passengers", color="green", marker="*", markersize=10, errorbar=None)

plt.title('Monthly Flight Passengers (Yearly Average)')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %% [markdown]
# ## 오후

# %%
data = {
'date': ['2024-01-01','2024-01-02','2024-01-03','2024-01-04','2024-01-05',
'2024-01-06','2024-01-07','2024-01-08'],
'category': ['A','B','A','B','A','B','A','B'],
'sales': [100, 150, 200, 130, 180, 170, 220, 160]
}

df = pd.DataFrame(data)
df
# Out:
#          date category  sales
# 0  2024-01-01        A    100
# 1  2024-01-02        B    150
# 2  2024-01-03        A    200
# 3  2024-01-04        B    130
# 4  2024-01-05        A    180
# 5  2024-01-06        B    170
# 6  2024-01-07        A    220
# 7  2024-01-08        B    160

# %%
pd.to_datetime(df['date'])
# Out:
# 0   2024-01-01
# 1   2024-01-02
# 2   2024-01-03
# 3   2024-01-04
# 4   2024-01-05
# 5   2024-01-06
# 6   2024-01-07
# 7   2024-01-08
# Name: date, dtype: datetime64[us]

# %%
df['date'] = df['date'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      8 non-null      str
#  1   category  8 non-null      str
#  2   sales     8 non-null      int64
# dtypes: int64(1), str(2)
# memory usage: 324.0 bytes

# %%
# 카테고리 별 총 매출을 구하라.

df.groupby('category')['sales'].sum() 
df.groupby('category')['sales'].apply(sum) 
df.groupby('category')[['sales']].agg(sum)
# Out:
#           sales
# category
# A           700
# B           610

# %%
table = df.groupby('category', as_index=False)[['sales']].agg(sum)

sns.barplot(data=table, x='category', y='sales', hue='category', dodge = False)
# Out:
# <Axes: xlabel='category', ylabel='sales'>

# %%
game = pd.DataFrame({'시리즈':['mario','mario','mario','pokémon','pokémon','pokémon','zelda','zelda','zelda'],
                    '타이틀':['Wonder','ODYSSEY','GALAXY2','S/V','PLA','Z-A','BotW','TotK','OoT'],
                    '출시일':['2023-10-20','2017-12-01','2011-01-20','2022-11-18','2022-01-28','2025-10-16','2018-02-01','2023-05-12','2012-09-27'],
                    '판매량':[1715,3027,741,2808,1500,1230,3364,2240,644],
                    '가격':[64800,64800,44800,64800,79800,64800,74800,84800,29000]})

game
# Out:
#        시리즈      타이틀         출시일   판매량     가격
# 0    mario   Wonder  2023-10-20  1715  64800
# 1    mario  ODYSSEY  2017-12-01  3027  64800
# 2    mario  GALAXY2  2011-01-20   741  44800
# 3  pokémon      S/V  2022-11-18  2808  64800
# 4  pokémon      PLA  2022-01-28  1500  79800
# 5  pokémon      Z-A  2025-10-16  1230  64800
# 6    zelda     BotW  2018-02-01  3364  74800
# 7    zelda     TotK  2023-05-12  2240  84800
# 8    zelda      OoT  2012-09-27   644  29000

# %%
# 판매량과 가격을 곱하여 매출란을 추가하시오.

game['매출'] = game['판매량'] * game['가격']
game
# Out:
#        시리즈      타이틀         출시일   판매량     가격         매출
# 0    mario   Wonder  2023-10-20  1715  64800  111132000
# 1    mario  ODYSSEY  2017-12-01  3027  64800  196149600
# 2    mario  GALAXY2  2011-01-20   741  44800   33196800
# 3  pokémon      S/V  2022-11-18  2808  64800  181958400
# 4  pokémon      PLA  2022-01-28  1500  79800  119700000
# 5  pokémon      Z-A  2025-10-16  1230  64800   79704000
# 6    zelda     BotW  2018-02-01  3364  74800  251627200
# 7    zelda     TotK  2023-05-12  2240  84800  189952000
# 8    zelda      OoT  2012-09-27   644  29000   18676000

# %%
# 시리즈별로 판매량 (합) 가격 (평균) 매출 (합)

df = game.groupby('시리즈')[['판매량', '가격', '매출']].agg({'판매량' : 'sum', '가격' : 'mean', '매출' : 'sum'})
df

#df = game.groupby('시리즈', as_index=False)[['판매량', '가격', '매출']].agg({'판매량' : 'sum', '가격' : 'mean', '매출' : 'sum'})
# Out:
#           판매량            가격         매출
# 시리즈
# mario    5483  58133.333333  340478400
# pokémon  5538  69800.000000  381362400
# zelda    6248  62866.666667  460255200

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

sns.scatterplot(data = df, x = '가격', y = '매출', hue = '시리즈')
# Out:
# <Axes: xlabel='가격', ylabel='매출'>

# %%
df1 = game.groupby(['시리즈', '타이틀'], as_index=False)[['매출']].agg(sum)
df1
# Out:
#        시리즈      타이틀         매출
# 0    mario  GALAXY2   33196800
# 1    mario  ODYSSEY  196149600
# 2    mario   Wonder  111132000
# 3  pokémon      PLA  119700000
# 4  pokémon      S/V  181958400
# 5  pokémon      Z-A   79704000
# 6    zelda     BotW  251627200
# 7    zelda      OoT   18676000
# 8    zelda     TotK  189952000

# %%
sns.barplot(data = df1, x = '시리즈', y = '매출', hue = '타이틀')
# Out:
# <Axes: xlabel='시리즈', ylabel='매출'>

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 요일별로 total_bill 의 평균과 tip 의 평균을 구하여라

tips.groupby('day', as_index=False)[['total_bill', 'tip']].agg('mean')
# Out:
#     day  total_bill       tip
# 0  Thur   17.682742  2.771452
# 1   Fri   17.151579  2.734737
# 2   Sat   20.441379  2.993103
# 3   Sun   21.410000  3.255132

# %%
# total bill 에 대한 tip 의 비율인 tip_rate 칼럼을 만들어 봅시다.

tips['tip_rate'] = tips['tip'] / tips['total_bill']* 100
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_rate
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %% [markdown]
# # 4월 7일

# %% [markdown]
# ## 오전

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg = sns.load_dataset('mpg')
mpg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    str
#  8   name          398 non-null    str
# dtypes: float64(4), int64(3), str(2)
# memory usage: 28.1 KB

# %%
# mpg 데이터셋 에서 결측치 확인.

mpg.isnull().sum()['horsepower']
# Out:
# np.int64(6)

# %%
# null 6개를 평균값으로 채워넣어 주세요.

avg = mpg['horsepower'].mean()
mpg['horsepower'] = mpg['horsepower'].fillna(avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # null 6개를 평균값으로 채워넣어 주세요.
# ----> 3 avg = mpg['horsepower'].mean()
#       4 mpg['horsepower'] = mpg['horsepower'].fillna(avg)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %% [markdown]
# ## 오후

# %%
planets = sns.load_dataset('planets')

planets.info()
planets.describe()

# 결측치 개수
planets.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   str
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), str(1)
# memory usage: 48.6 KB
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
# mass 의 상자수염그림을 그려주세요.

sns.boxplot(data=planets, y = 'mass')
# Out:
# <Axes: ylabel='mass'>

# %% [markdown]
# - 수염의 길이 구하기

# %%
IQR = (planets['mass'].quantile(.75) - planets['mass'].quantile(.25))

IQR
# Out:
# np.float64(2.811)

# %%
upper = planets['mass'].quantile(.75) + 1.5 * IQR
upper
# Out:
# np.float64(7.2565)

# %%
lower = planets['mass'].quantile(.25) - 1.5 * IQR
lower
# Out:
# np.float64(-3.9875)

# %%
# 이상치만 모아주세요.
# - 이상치들의 평균은

outlier_upper = planets[planets['mass'] > upper]
outlier = planets.query('mass > @upper')
outlier
# Out:
#               method  number  orbital_period     mass  distance  year
# 3    Radial Velocity       1      326.030000  19.4000    110.62  2007
# 4    Radial Velocity       1      516.220000  10.5000    119.47  2009
# 8    Radial Velocity       1      993.300000  10.3000     73.10  2008
# 11   Radial Velocity       1      335.100000   9.8800     39.43  2009
# 50   Radial Velocity       1      594.900000   7.6000     47.53  2006
# 51   Radial Velocity       1      428.500000   8.7800     38.52  2009
# 63   Radial Velocity       1      305.500000  20.6000     92.51  2013
# 77   Radial Velocity       1      714.300000  10.6000       NaN  2007
# 85   Radial Velocity       2      379.630000  21.4200       NaN  2009
# 86   Radial Velocity       2      621.990000  12.4700       NaN  2009
# 161  Radial Velocity       2      428.500000  15.2000    214.00  2009
# 218  Radial Velocity       1      177.110000   7.6000    150.60  2011
# ...

# %%
normal = planets.query('mass <= @upper')

# %%
# 가장 가까운 행 데이터는?

planets.query('distance == distance.min()')
# Out:
#              method  number  orbital_period    mass  distance  year
# 46  Radial Velocity       1          3.2357  0.0036      1.35  2012

# %%
# mass 와 distance 산점도 (year 색상매김)

sns.scatterplot(data=planets, x='mass', y='distance', hue = 'year', palette = 'Set1')
# Out:
# <Axes: xlabel='mass', ylabel='distance'>

# %%
tomatoes = pd.DataFrame({'영화':['Iron Man','Ant-Man and the Wasp: Quantumania','Guardians of the Galaxy','Doctor Strange',
                               'Spider-Man: No Way Home','Avengers: Endgame','Eternals',
                               'Thor: Love and Thunder','Black Widow'],'점수':[94,46,85,89,93,94,47,63,79]})

tomatoes
# Out:
#                                   영화  점수
# 0                           Iron Man  94
# 1  Ant-Man and the Wasp: Quantumania  46
# 2            Guardians of the Galaxy  85
# 3                     Doctor Strange  89
# 4            Spider-Man: No Way Home  93
# 5                  Avengers: Endgame  94
# 6                           Eternals  47
# 7             Thor: Love and Thunder  63
# 8                        Black Widow  79

# %%
# 표의 점수가 86점 이상은 'A'
# 60 점 이상 86 점 미만은 'B'
# 60점 미만은 'C' 가 되도록

tomatoes['등급'] = np.where(tomatoes['점수'] >= 86, 
                          'A', np.where(tomatoes['점수'] >= 60, 'B', 'C' ))

tomatoes
# Out:
#                                   영화  점수 등급
# 0                           Iron Man  94  A
# 1  Ant-Man and the Wasp: Quantumania  46  C
# 2            Guardians of the Galaxy  85  B
# 3                     Doctor Strange  89  A
# 4            Spider-Man: No Way Home  93  A
# 5                  Avengers: Endgame  94  A
# 6                           Eternals  47  C
# 7             Thor: Love and Thunder  63  B
# 8                        Black Widow  79  B

# %%
# pd.cut 을 사용한 방법

tomatoes['등급'] = pd.cut(tomatoes['점수'], 
                        bins=[0, 60, 86, 100], 
                        labels = ['C', 'B', 'A'])

tomatoes
# Out:
#                                   영화  점수 등급
# 0                           Iron Man  94  A
# 1  Ant-Man and the Wasp: Quantumania  46  C
# 2            Guardians of the Galaxy  85  B
# 3                     Doctor Strange  89  A
# 4            Spider-Man: No Way Home  93  A
# 5                  Avengers: Endgame  94  A
# 6                           Eternals  47  C
# 7             Thor: Love and Thunder  63  B
# 8                        Black Widow  79  B

# %%
# apply 함수 사용

def grade(score):
    if score >= 86:
        return 'A'

    elif score >= 60:
        return 'B'

    else:
        return 'C'

# %%
score = pd.DataFrame({'한화':[4,0,0,1,0,0,0,0,0],'LG':[0,5,2,3,0,0,1,2,0]}, index=[i for i in range(1,10) ] )
score

# 9회 초에 lg의 우승이 확정되어 9회말은 경기를 하지 않았다. lg의 9회를 바꾸시오.

score.iloc[-1, -1] = np.nan

# score.iloc[8, 1]
# score['LG'][9] = np.nan

# %% [markdown]
# # 4월 8일

# %% [markdown]
# ## 오전

# %%
import pandas as pd
import numpy as np

# %%
movie = pd.DataFrame({'영화':['데드풀','겟 아웃','닥터 스트레인지 2','위대한 쇼맨','미드 소마','알라딘'],
                     '장르1':['히어로','공포','히어로','뮤지컬','공포','뮤지컬'],
                     '장르2':['블랙코미디','미스터리','공포','드라마','미스터리','판타지'],
                     '로튼토마토': [85,98,73,56,83,59]  })

movie
# Out:
#            영화  장르1    장르2  로튼토마토
# 0         데드풀  히어로  블랙코미디     85
# 1        겟 아웃   공포   미스터리     98
# 2  닥터 스트레인지 2  히어로     공포     73
# 3      위대한 쇼맨  뮤지컬    드라마     56
# 4       미드 소마   공포   미스터리     83
# 5         알라딘  뮤지컬    판타지     59

# %%
# melt 를 이용하여 아래의 표를 만드세요.

melted = movie.melt(id_vars = ['영화', '로튼토마토'], value_vars = ['장르1', '장르2'],
                    var_name = '순번',value_name = '장르')

melted
# Out:
#             영화  로튼토마토   순번     장르
# 0          데드풀     85  장르1    히어로
# 1         겟 아웃     98  장르1     공포
# 2   닥터 스트레인지 2     73  장르1    히어로
# 3       위대한 쇼맨     56  장르1    뮤지컬
# 4        미드 소마     83  장르1     공포
# 5          알라딘     59  장르1    뮤지컬
# 6          데드풀     85  장르2  블랙코미디
# 7         겟 아웃     98  장르2   미스터리
# 8   닥터 스트레인지 2     73  장르2     공포
# 9       위대한 쇼맨     56  장르2    드라마
# 10       미드 소마     83  장르2   미스터리
# 11         알라딘     59  장르2    판타지

# %% [markdown]
# - pivot()을 이용하여 wide 형으로 바꾸어 봅시다.

# %%
pivoted = melted.pivot(index = ['영화', '로튼토마토'], columns = '순번', values = '장르')

pivoted.reset_index()
# Out:
# 순번          영화  로튼토마토  장르1    장르2
# 0         겟 아웃     98   공포   미스터리
# 1   닥터 스트레인지 2     73  히어로     공포
# 2          데드풀     85  히어로  블랙코미디
# 3        미드 소마     83   공포   미스터리
# 4          알라딘     59  뮤지컬    판타지
# 5       위대한 쇼맨     56  뮤지컬    드라마

# %%
data = {
    "이름": ["철수", "영희", "민수", "지수", "현우"],
    "수학": [90, np.nan, 70, 85, 60],
    "영어": [80, 75, np.nan, 90, 65],
    "과학": [np.nan, 85, 60, 95, 70]}

df = pd.DataFrame(data)


# 수학 평균으로 채우기
math_avg = df['수학'].mean()
df['수학'] = df['수학'].fillna(math_avg)

# 영어 평균으로 채우기
eng_avg = df['영어'].mean()
df['영어'] = df['영어'].fillna(eng_avg)

# 과학 평균으로 채우기
sci_avg = df['과학'].mean()
df['과학'] = df['과학'].fillna(sci_avg)

df
# Out:
#    이름     수학    영어    과학
# 0  철수  90.00  80.0  77.5
# 1  영희  76.25  75.0  85.0
# 2  민수  70.00  77.5  60.0
# 3  지수  85.00  90.0  95.0
# 4  현우  60.00  65.0  70.0

# %%
plt.rc('font', family='Malgun Gothic')

df_melted = df.melt(id_vars='이름', value_vars=['수학','영어','과학'], var_name='과목', value_name='점수')

sns.barplot(data=df_melted, x='이름', y='점수', hue='과목', palette='Set2')
plt.show()

# %% [markdown]
# # 4월 9일

# %% [markdown]
# ## 오전

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.DataFrame({'id':[1,2,3], 'name':['A','B','C']})
df2 = pd.DataFrame({'id':[2,3,4], 'score':[90,85,80]})

print(df1)
df2
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C
#    id  score
# 0   2     90
# 1   3     85
# 2   4     80

# %%
df1.merge(df2)
df1.merge(df2, on = 'id')
df1.merge(df2, left_on = 'id', right_on='id')
df1.merge(df2, left_on = 'id', right_on='id', how="inner")
# Out:
#    id name  score
# 0   2    B     90
# 1   3    C     85

# %%
df1.merge(df2,how = 'left', on = 'id')
# Out:
#    id name  score
# 0   1    A    NaN
# 1   2    B   90.0
# 2   3    C   85.0

# %%
df1 = pd.DataFrame({'user_id':[1,2,3], 'name':['A','B','C']})
df2 = pd.DataFrame({'id':[2,3,4], 'score':[90,85,80]})

print(df1)
df2
# Out:
#    user_id name
# 0        1    A
# 1        2    B
# 2        3    C
#    id  score
# 0   2     90
# 1   3     85
# 2   4     80

# %%
df1.merge(df2, left_on = 'user_id', right_on = 'id')
# Out:
#    user_id name  id  score
# 0        2    B   2     90
# 1        3    C   3     85

# %%
customers = pd.DataFrame({
    '고객번호': [1, 2, 3],
    '이름': ['주지훈', '정유미', '박민영']})

orders = pd.DataFrame({
    '주문번호': [101, 102, 103],
    '고객번호': [1, 2, 1],
    '상품': ['A상품', 'B상품', 'C상품']})

print(customers)
orders
# Out:
#    고객번호   이름
# 0     1  주지훈
# 1     2  정유미
# 2     3  박민영
#    주문번호  고객번호   상품
# 0   101     1  A상품
# 1   102     2  B상품
# 2   103     1  C상품

# %%
# 두 데이터를 합쳐주세요.

co = pd.merge(customers, orders, on = '고객번호', how = 'left')
co
# Out:
#    고객번호   이름   주문번호   상품
# 0     1  주지훈  101.0  A상품
# 1     1  주지훈  103.0  C상품
# 2     2  정유미  102.0  B상품
# 3     3  박민영    NaN  NaN

# %%
# 강사님이 한거

customers.merge(orders)
customers.merge(orders, how='outer')
# Out:
#    고객번호   이름   주문번호   상품
# 0     1  주지훈  101.0  A상품
# 1     1  주지훈  103.0  C상품
# 2     2  정유미  102.0  B상품
# 3     3  박민영    NaN  NaN

# %%
flights = sns.load_dataset('flights')


# 'passengers' 를 오름차순으로 정렬하기
flights.sort_values('passengers', ignore_index = True)

# 'passengers' 를 내림차순으로 정렬하기
flights.sort_values('passengers', ascending = False)

# 상위 다섯개 
flights.sort_values('passengers', ascending = False)[:5]
# Out:
#      year month  passengers
# 138  1960   Jul         622
# 139  1960   Aug         606
# 127  1959   Aug         559
# 126  1959   Jul         548
# 137  1960   Jun         535

# %%
flights

f1 = flights[['year', 'month']]
f2 = flights[['year', 'passengers']]

# f1 과 f2 를 다시 복구

f1.merge(f2)
# Out:
#       year month  passengers
# 0     1949   Jan         112
# 1     1949   Jan         118
# 2     1949   Jan         132
# 3     1949   Jan         129
# 4     1949   Jan         121
# ...    ...   ...         ...
# 1723  1960   Dec         606
# 1724  1960   Dec         508
# 1725  1960   Dec         461
# 1726  1960   Dec         390
# 1727  1960   Dec         432
#
# [1728 rows x 3 columns]
