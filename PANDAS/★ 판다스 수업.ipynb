# %% [markdown]
# # 판다스 0326 ~

# %%
import pandas as pd

# %% [markdown]
# ## 파일열기

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\pandas'

# %%
# 교재 29 p ~

# working directory : 작업 디렉토리 ( directory 와 folder 같은 의미) 가 필요하다.

# 현재 working directory 를 보려면.. ( import os 한 후 > os.getcwd()) 하면됨.

# %%
# make directory = os.mkdir("pandas")

os.mkdir("pandas")

# %% [markdown]
# - csv 란
# ```
# comma separated value > csv ; 메모장에서 쉼표로 쓰여져 있는거.
# tab separated value > tsv ; 메모장에서 쉼표 대신 tab 으로 쓰여져 있는거.
#
# ```

# %%
# 갭 마인더 데이터 셋을 불러올거임

pd.read_csv("data/gapminder.tsv", sep='\t') # sep = separate 분리 (tab 으로 분리)

# data 밑에 파일이 있다.
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
# pd.read_csv("data/billboard.csv") > 이렇게도 씀.

pd.read_csv("./data/billboard.csv") # ./ 를 앞에 써주면 내 위치에서 라는 뜻

# billboard 일 때는 separate 를 쓰지 않는다.
# Out:
#      year            artist                    track  time date.entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
# df로 명칭

df = pd.read_csv("data/gapminder.tsv", sep='\t')
df

# 교재 ~ 30p 까지..
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
df.shape # type = 튜플
# Out:
# (1704, 6)

# %% [markdown]
# ### 데이터 프레임 이해하기

# %%
# 몇 행 몇 열인가?
row, column = df.shape
print(row)
print(column)
# Out:
# 1704
# 6

# %%
df.shape[0]
df.shape[1]
# Out:
# 6

# %%
# 칼럼들의 이름은?

df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='str')

# %%
for i in df.columns:
    print(i)
# Out:
# country
# continent
# year
# lifeExp
# pop
# gdpPercap

# %%
# 전체 정보

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   str
#  1   continent  1704 non-null   str
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), str(2)
# memory usage: 80.0 KB

# %%
# 일부만 보기

df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# 일부만 보기 > 앞에 열개

print(df.head())
print(df.head(10))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# ...

# %%
# 일부만 보기 > 뒤에  5개

print(df.tail())
print(df.tail(10))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# ...

# %% [markdown]
# ### list 로 열 데이터 추출

# %%
# 칼럼 한 개 뽑을 때
print(df['lifeExp'])

# 칼럼 두개 이상 뽑을 때
df[['lifeExp', 'pop']] # 바깥쪽 대괄호는 열을 추출한다는 뜻이고, 안쪽 대괄호는 추출할 열 리스트
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: lifeExp, Length: 1704, dtype: float64
#       lifeExp       pop
# 0      28.801   8425333
# 1      30.332   9240934
# 2      31.997  10267083
# 3      34.020  11537966
# 4      36.088  13079460
# ...       ...       ...
# 1699   62.351   9216418
# 1700   60.377  10704340
# 1701   46.809  11404948
# 1702   39.989  11926563
# 1703   43.487  12311143
#
# [1704 rows x 2 columns]

# %% [markdown]
# ### 행 뽑기
# ```
# df.loc[  : 10 , ['country, 'year'] ]
# - df.loc > location 행, 열 이름이 글자일 때
# > 문자 열 일 때는 인댁싱이 안된다. ex ['country : year'] < 이거 안된다는 얘기..
#
# df.iloc[  :  ,  :  ]
# - df.iloc > integer location 행과 열의 이름이 숫자일 때
# ```

# %%
df.loc[  : 10 , ['country', 'year'] ] # 문자 열 일 때는 인댁싱이 안된다.
df.iloc[  : 10 , 0 : 3 ]
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
# 5  Afghanistan      Asia  1977
# 6  Afghanistan      Asia  1982
# 7  Afghanistan      Asia  1987
# 8  Afghanistan      Asia  1992
# 9  Afghanistan      Asia  1997

# %%
# 접근합니다. [ 시작 행 : 끝나는 행 + 1 , 시작 열: 끝나는 열]

df.iloc[2 : 5, 2: ] # iloc 붙여줘야하는게 key point
# Out:
#    year  lifeExp       pop   gdpPercap
# 2  1962   31.997  10267083  853.100710
# 3  1967   34.020  11537966  836.197138
# 4  1972   36.088  13079460  739.981106

# %%
# 짝수 행 열 만 출력하기

df.iloc[: :2, 1: :2] # [시작 : 스탑 : 스텝]
# Out:
#      continent  lifeExp   gdpPercap
# 0         Asia   28.801  779.445314
# 2         Asia   31.997  853.100710
# 4         Asia   36.088  739.981106
# 6         Asia   39.854  978.011439
# 8         Asia   41.674  649.341395
# ...        ...      ...         ...
# 1694    Africa   52.358  527.272182
# 1696    Africa   55.635  799.362176
# 1698    Africa   60.363  788.855041
# 1700    Africa   60.377  693.420786
# 1702    Africa   39.989  672.038623
#
# [852 rows x 3 columns]

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[0, : ]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[0:2, 2:5 ]

# df.iloc[0:2, range(2, 5)] 해도 된다..
# Out:
#    year  lifeExp      pop
# 0  1952   28.801  8425333
# 1  1957   30.332  9240934

# %%
df.iloc[ [1, 3, 5] , [1, 3, 4]]

# 57 p 맨 위 "2번" 내용
# Out:
#   continent  lifeExp       pop
# 1      Asia   30.332   9240934
# 3      Asia   34.020  11537966
# 5      Asia   38.438  14880372

# %% [markdown]
# ## 시리즈 Seiries
# - 한 줄

# %%
df.iloc[0, :]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[:, 0]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: str

# %% [markdown]
# - 시리즈 만들기

# %%
s = pd.Series([1, 2, 3, "a", "b", "c"])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    a
# 4    b
# 5    c
# dtype: object

# %%
s = pd.Series([1, 2, 3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# index 직접 지정하기

s = pd.Series([1, 2, 3], index = ['철수', '영희', '길동'])
s
# Out:
# 철수    1
# 영희    2
# 길동    3
# dtype: int64

# %%
s = pd.Series([1,1,1,2,2,2,2,3,3])
s
s.value_counts()
# Out:
# 2    4
# 1    3
# 3    2
# Name: count, dtype: int64

# %%
scientists = pd.DataFrame({
        "Name": ["Rosaline Franklin", "William Gosset"],
        "Occupation": ["Chemist", "Statistician"],
        "Born": ["1920-07-25", "1876-06-13"],
        "Died": ["1958-04-16", "1937-10-16"],
        "Age": [37, 61],
})

scientists
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %%
# 시리즈로 한 행 뽑기

scientists.iloc[ :, 0]
scientists.iloc[0, :]
# Out:
# Name          Rosaline Franklin
# Occupation              Chemist
# Born                 1920-07-25
# Died                 1958-04-16
# Age                          37
# Name: 0, dtype: object

# %%
s = scientists.iloc[0, :]
type(s)
# Out:
# pandas.Series

# %%
s['Name']

# s.loc['Name'] 이렇게 써도 된다.
# Out:
# 'Rosaline Franklin'

# %%
s.index
# Out:
# Index(['Name', 'Occupation', 'Born', 'Died', 'Age'], dtype='str')

# %%
ages = scientists.loc[:, 'Age']

# %%
max([1, 2, 3])
min([1, 2, 3])
sum([1, 2, 3])
# Out:
# 6

# %%
s = pd.Series([1, 2, 3])
print(s.min())
print(s.max())
print(s.sum())
print(s.mean())
# Out:
# 1
# 3
# 6
# 2.0

# %%
a = np.array([1, 2, 3])
print(a.min())
print(a.max())
print(a.sum())
print(a.mean())
# Out:
# 1
# 3
# 6
# 2.0

# %%
s.values

# 값 만 알고 싶을 때
# Out:
# array(['Rosaline Franklin', 'Chemist', '1920-07-25', '1958-04-16',
#        np.int64(37)], dtype=object)

# %%
s.value_counts()
# Out:
# 0
# Rosaline Franklin    1
# Chemist              1
# 1920-07-25           1
# 1958-04-16           1
# 37                   1
# Name: count, dtype: int64

# %%
s.shape

# 행이 5개 라는 뜻. 뒤에 비워져 있는건 열이 없다는 뜻. (1행, 0열)
# 이를 1차원이라고 한다.
# Out:
# (5,)

# %%
s.size

# 안에 몇개가 있는지 알고 싶을 때
# Out:
# 5

# %% [markdown]
# - scientists.iloc[0, : ] 와 scientists.iloc[[0] ,  :] 출력 상태 비교

# %%
# 시라즈로 한 행 뽑기

scientists.iloc[0, : ]
# Out:
# Name          Rosaline Franklin
# Occupation              Chemist
# Born                 1920-07-25
# Died                 1958-04-16
# Age                          37
# Name: 0, dtype: object

# %%
# 데이터 프레임으로 한 행 뽑기

scientists.iloc[[0] ,  :]
# Out:
#                 Name Occupation        Born        Died  Age
# 0  Rosaline Franklin    Chemist  1920-07-25  1958-04-16   37

# %%
s1 = scientists.iloc[[0] ,  :]
s1. shape

# 1행 5열 이라는 뜻.
# 이거는 2차원이다.
# Out:
# (1, 5)

# %%
df = pd.read_csv("./data/scientists.csv")
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
df.loc[:, 'Age']
age1 = df['Age']
age2 = df['Age']

# %%
age1 + age2

# 더해진다.
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %%
age2
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
age2.sort_values()

# sorting 을 해도 index 번호는 따라감
# Out:
# 0    37
# 6    41
# 5    45
# 4    56
# 1    61
# 3    66
# 7    77
# 2    90
# Name: Age, dtype: int64

# %%
age3 = age2.sort_values()

# %%
# age2 를 age3에 입힌 후 age 1 과 더하면 어떻게 될까

age1 + age3
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# - 결과 ; index 를 찾아가서 index 기준으로 계산된 걸 볼 수 있다.

# %%
age = df['Age']
age
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
print(age.min())
print(age.max())
print(age.mean())
print(age.quantile())
print(age.median())
print(age.describe()) # describe 는  다 계산해준다.
# Out:
# 37
# 90
# 59.125
# 58.5
# 58.5
# count     8.000000
# mean     59.125000
# std      18.325918
# min      37.000000
# 25%      44.000000
# 50%      58.500000
# 75%      68.750000
# max      90.000000
# Name: Age, dtype: float64

# %%
age == 90
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Age, dtype: bool

# %% [markdown]
# - a > 60 : element - wise 하게 작동한다.
#
# - a [ 참 거짓 ] : 참 인 것만 골라낸다. (검색 용도로 사용 가능)

# %%
age > 60

age[ age > 60 ]
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
age[age > age.mean()]

# 평균 보다 높은 것 만 골라라
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
a = np.array([1, 2, 3])
b = np.array([3, 2, 1])

# %%
a + b
a * b
# Out:
# array([3, 4, 3])

# %%
a = np.array([[1, 2, 3],[1, 2, 3]])
b = np.array([[3, 2, 1],[3, 2, 1]])

# %%
a

# element - wise 끼리끼리 맞춰서 연산한다.
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
b
# Out:
# array([[3, 2, 1],
#        [3, 2, 1]])

# %%
a == b
# Out:
# array([[False,  True, False],
#        [False,  True, False]])

# %%
a + b
a * b
# Out:
# array([[3, 4, 3],
#        [3, 4, 3]])

# %%
pd.DataFrame(a)
# Out:
#    0  1  2
# 0  1  2  3
# 1  1  2  3

# %% [markdown]
# Numpy 기능
# - element wising
#   >
#
# - broad casiting
#   > a 는 2 차원 b 는 1차원 일 때도 b 를 알아서 2차원으로 만들어서 계산함.

# %% [markdown]
# ## 데이터 프레임 DataFrame

# %% [markdown]
# ### 만들기
#  - 방법 1 : pd.DataFrame ([리스트들])
#    > 라로로 들어간다. 하나의 큰 리스트로 묶는다.  ex. [[ x, y, z] , [a, b, d]]
#  - 방법 2 : pd.DataFrame (딕셔너리)
#    > {key : value}  에서 key 는 칼럼이름, value 는 세로로 들어간다.

# %%
# 가로로 쓰여짐 

pd.DataFrame([[1,2,3] , ['a', 'b', 'c']])

pd.DataFrame([[1,2,3] , ['a', 'b', 'c']],  index=['철수', '영희'], columns=['영어', '수학', '과학'])
# Out:
#    영어 수학 과학
# 철수  1  2  3
# 영희  a  b  c

# %%
# 세로로 쓰여짐

pd.DataFrame({"영어" : [1, 'a'], "수학" : [2, 'b'], "과학" : [3, 'c']})
pd.DataFrame({"영어" : [1, 'a'], "수학" : [2, 'b'], "과학" : [3, 'c']}, index = ['철수', '영희'])
# Out:
#    영어 수학 과학
# 철수  1  2  3
# 영희  a  b  c

# %%
s1 = pd.Series([1, 2, 3])
s2 = pd.Series(['a', 'b', 'c'])
s1
s2
# Out:
# 0    a
# 1    b
# 2    c
# dtype: str

# %%
pd.DataFrame([s1, s2])
# Out:
#    0  1  2
# 0  1  2  3
# 1  a  b  c

# %% [markdown]
# - 판다스의 시리즈 자료는 numpy 자료에 의존성을 가지고 있다.

# %% [markdown]
# - array; 배열
# - ndarray; shape > ex. 1차원 (1D) 어레이, 2차원 2(D) 어레이

# %%
import numpy as np
type(np.array([1, 2, 3]))
# Out:
# numpy.ndarray

# %%
a = np.array([1, 2, 3])
type(a)
# Out:
# numpy.ndarray

# %%
a.size
# Out:
# 3

# %%
a.shape

# 1차원 어레이 > 1D array
# Out:
# (2, 3)

# %%
b = np.array([[1, 2, 3], [4, 5, 6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b.shape

# 2차원 어레이 > 2D array
# Out:
# (2, 3)

# %%
c = np.array([[[1, 2, 3], [4, 5, 6]],[[1, 2, 3], [4, 5, 10]]])
c
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6]],
#
#        [[ 1,  2,  3],
#         [ 4,  5, 10]]])

# %%
c.shape

# 3차원 어레이 > 3D array
# Out:
# (2, 2, 3)

# %% [markdown]
# ```
# - vector; 한 줄 ( 1차원 자료 = (5, ) 이렇게 생긴 거)
#   > [1, 2, 3, 4, 5] 리스트이면서 시리즈 이면서 vector
#   > 이제 vector라고 말할거임
#
#
# ```

# %%
# scientists 불러오기

df = pd.read_csv("./data/scientists.csv")
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
# df[ : ] 행을 불러오려면 슬라이싱해주면 된다.

df[ : 2]
# Out:
#                 Name        Born        Died  Age    Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician

# %%
# df.info()
# df.describe()
# df.index
df.columns
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation'], dtype='str')

# %%
# 평균 나이보다 나이가 많은 사람들을 뽑고 싶다.

df[df['Age'] > df['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
# 직업이 Nurse 인 사람

df[df['Occupation'] == "Nurse"]
# Out:
#                    Name        Born        Died  Age Occupation
# 2  Florence Nightingale  1820-05-12  1910-08-13   90      Nurse

# %% [markdown]
# ### 열 삭제하기

# %%
df[:2]
df.drop("Born", axis = 1)
# Out:
#                    Name        Died  Age          Occupation
# 0     Rosaline Franklin  1958-04-16   37             Chemist
# 1        William Gosset  1937-10-16   61        Statistician
# 2  Florence Nightingale  1910-08-13   90               Nurse
# 3           Marie Curie  1934-07-04   66             Chemist
# 4         Rachel Carson  1964-04-14   56           Biologist
# 5             John Snow  1858-06-16   45           Physician
# 6           Alan Turing  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1855-02-23   77       Mathematician

# %%
df = pd.DataFrame({'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
        '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}, index = ['철수', '영희', '길동'])

df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85  100
# 영희  80  89   95   90
# 길동  70  95  100   90

# %% [markdown]
# - drop 후 덮어쓰지 않으면 따로 저장이 되지 않는다.

# %%
# 행 지우기

df.drop("철수")
# Out:
#     수학  영어   음악  체육
# 영희  80  89   95  90
# 길동  70  95  100  90

# %%
# 열 지우기

df.drop("수학", axis=1)
# Out:
#     영어   음악   체육
# 철수  98   85  100
# 영희  89   95   90
# 길동  95  100   90

# %%
# 행, 열 삭제

df.drop(['수학', '영어'], axis = 1)
# Out:
#      음악   체육
# 철수   85  100
# 영희   95   90
# 길동  100   90

# %% [markdown]
# ```
# - 저장하는 두가지 방법
#   > df = df.drop('철수')
#   > df.drop("철수", inplace = True)
#
# ```

# %%
df = pd.DataFrame([ ['현수', 20, 85], ['영희', 22, 90], ['민수', 21, 78] ], 
             columns=['이름', '나이', '점수'])

df
# Out:
#    이름  나이  점수
# 0  현수  20  85
# 1  영희  22  90
# 2  민수  21  78

# %%
# 지우기보다는 덮었쓰는 형태

df = df[['나이', '점수']]
df
# Out:
#    나이  점수
# 0  20  85
# 1  22  90
# 2  21  78

# %%
# 아무것도 안쓰면 열로 구해짐 

df.sum()
# Out:
# 나이     63
# 점수    253
# dtype: int64

# %%
# 행으로 구하기

df.mean(axis=1)
# Out:
# 0    52.5
# 1    56.0
# 2    49.5
# dtype: float64

# %% [markdown]
# ### 값 수정

# %%
df = pd.DataFrame({'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
        '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}, index = ['철수', '영희', '길동'])

df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85  100
# 영희  80  89   95   90
# 길동  70  95  100   90

# %%
# 원소 한 개 수정 

df.iloc[1, 3] # 영희의 체육 점수.
df.iloc[1, 3] = 100
df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85  100
# 영희  80  89   95  100
# 길동  70  95  100   90

# %%
# 열의 값 수정

df['체육'] = 80 # 이렇게 하면 체육 열이 다 80으로 바뀜.
df['체육'] = [80, 90, 100] # 순서대로 적어주면 아래처럼 바뀜
df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85   80
# 영희  80  89   95   90
# 길동  70  95  100  100

# %%
# 있으면 수정 하고 없으면 만든다

df['채육'] = [80, 90, 100]
df
# Out:
#     수학  영어   음악   체육   채육
# 철수  90  98   85   80   80
# 영희  80  89   95   90   90
# 길동  70  95  100  100  100

# %%
df = pd.DataFrame({'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
        '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}, index = ['철수', '영희', '길동'])

df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85  100
# 영희  80  89   95   90
# 길동  70  95  100   90

# %%
# 국어 100, 80, 90 을 추가

df['국어'] = [100, 80, 90]
df
# Out:
#     수학  영어   음악   체육   국어
# 철수  90  98   85  100  100
# 영희  80  89   95   90   80
# 길동  70  95  100   90   90

# %%
# 총합 구하기.
df.sum() # 이렇게 하면 과목 별 총합이 나온다.
df.sum(axis = 1) # 각각 학생들의 총합

# 한 줄로 만들기

df['총합'] = df.sum(axis = 1)
df
# Out:
#     수학  영어   음악   체육   국어   총합
# 철수  90  98   85  100  100  473
# 영희  80  89   95   90   80  434
# 길동  70  95  100   90   90  445

# %%
# 평균 칼럼 추가

df['평균'] = df.iloc[:, :5].mean(axis = 1)
df
# Out:
#     수학  영어   음악   체육   국어   총합    평균
# 철수  90  98   85  100  100  473  94.6
# 영희  80  89   95   90   80  434  86.8
# 길동  70  95  100   90   90  445  89.0

# %%
df = pd.DataFrame({'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
        '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}, index = ['철수', '영희', '길동'])

df
# Out:
#     수학  영어   음악   체육
# 철수  90  98   85  100
# 영희  80  89   95   90
# 길동  70  95  100   90

# %%
np.sum(df) # 전체적인 합 1082

np.sum(df, axis = 0) # 과목 별 합
np.sum(df, axis = 1) # 개인 별 합
# Out:
# 철수    373
# 영희    354
# 길동    355
# dtype: int64

# %%
df.apply(np.sum, axis = 1)
# Out:
# 철수    373
# 영희    354
# 길동    355
# dtype: int64

# %%
df.apply(np.float32, axis = 1)

# df.apply(함수. 축방향)
# Out:
# 철수    [90.0, 98.0, 85.0, 100.0]
# 영희     [80.0, 89.0, 95.0, 90.0]
# 길동    [70.0, 95.0, 100.0, 90.0]
# dtype: object

# %%
def my_func(x):
    return x * 2

# %%
df.apply(my_func, axis = 1)
# Out:
#      수학   영어   음악   체육
# 철수  180  196  170  200
# 영희  160  178  190  180
# 길동  140  190  200  180

# %%
def func(x):
    return x.max() - x.min()

# %%
df.apply(func)
# Out:
# 수학    20
# 영어     9
# 음악    15
# 체육    10
# dtype: int64

# %%
df.apply(func)
df.apply(func, axis = 1)
# Out:
# 철수    15
# 영희    15
# 길동    30
# dtype: int64

# %%
df = pd.read_csv("data/gapminder.tsv", sep = '\t')
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# - 랜덤하게 일부만 추출하기
#
# ```
#    1) 랜덤한 index로 뽑기 - 일반적인 방법
#    2) df.sample 사용하기
#
# ```

# %%
df.iloc[ [1, 10, 25, 30], :]
# indices = random.sample(range(len(df)), 17) > 복원추출
# indices = np.random.choice(range(1, len(df)), size = 17, replace = False)
indices = np.random.choice(range(len(df)), size = int(len(df)*0.01), replace = False)

# df.iloc[indices , :]
# df[:2]

##################

# df.sample(17)
df.sample(frac = 0.01) # 행의 1% 만 출력 frac = fraction 비율.
# Out:
#             country continent  year  lifeExp        pop     gdpPercap
# 284           Chile  Americas  1992   74.126   13572994   7596.125964
# 1326        Senegal    Africa  1982   52.379    6147783   1518.479984
# 1628        Uruguay  Americas  1992   72.752    3149262   8137.004775
# 170          Brazil  Americas  1962   55.665   76039390   3336.585802
# 564         Germany    Europe  1952   67.500   69145952   7144.114393
# 997        Mongolia      Asia  1957   45.248     882134    912.662609
# 624   Guinea-Bissau    Africa  1952   32.500     580653    299.850319
# 1075          Nepal      Asia  1987   52.537   17917180    775.632450
# 1061        Namibia    Africa  1977   56.437     977026   3876.485958
# 1346   Sierra Leone    Africa  1962   32.767    2467895   1116.639877
# 705           India      Asia  1997   61.765  959000000   1458.817442
# 762          Israel      Asia  1982   74.450    3858421  15367.029200
# ...

# %%
import numpy as np

# %%
indices = random.sample(range(len(df)), 17)
df.iloc[indices, :]

# indices = index 복수형
# Out:
#                 country continent  year  lifeExp         pop     gdpPercap
# 957                Mali    Africa  1997   49.903     9384984    790.257985
# 1133            Nigeria    Africa  1977   44.514    62209173   1981.951806
# 1515           Tanzania    Africa  1967   45.757    12607312    848.218657
# 1679        Yemen, Rep.      Asia  2007   62.698    22211743   2280.769906
# 296               China      Asia  1992   68.690  1164970000   1655.784158
# 1245           Portugal    Europe  1997   75.970    10156415  17641.031560
# 1201               Peru  Americas  1957   46.263     9146100   4245.256698
# 587               Ghana    Africa  2007   60.022    22873338   1327.608910
# 8           Afghanistan      Asia  1992   41.674    16317921    649.341395
# 484   Equatorial Guinea    Africa  1972   40.516      277603    672.412257
# 684             Iceland    Europe  1952   72.490      147962   7267.688428
# ...

# %%
np.random.randint(1, 10, size = 5)
np.random.choice(range(1, len(df)), 17)
# Out:
# array([1556,  254,  220, 1146,  264, 1670,  562,  172,  216,   18, 1274,
#         848, 1139,  441,  657,  142,  303])

# %% [markdown]
# ## 저장하기
# ```
# 1) csv
# 2) excel
# 3) pickle
# ```

# %%
df.sample(frac = 0.01)
# Out:
#                country continent  year  lifeExp        pop     gdpPercap
# 1497             Syria      Asia  1997   71.527   15081016   4014.238972
# 81             Austria    Europe  1997   77.510    8069876  29095.920660
# 1116             Niger    Africa  1952   37.444    3379468    761.879376
# 1087       Netherlands    Europe  1987   76.830   14665278  23651.323610
# 829   Korea, Dem. Rep.      Asia  1957   54.081    9411381   1571.134655
# 138            Bolivia  Americas  1982   53.859    5642224   3156.510452
# 1211              Peru  Americas  2007   71.421   28674757   7408.905561
# 1240          Portugal    Europe  1972   69.260    8970450   9022.247417
# 1669       Yemen, Rep.      Asia  1957   33.970    5498090    804.830455
# 623             Guinea    Africa  2007   56.007    9947814    942.654211
# 1139           Nigeria    Africa  2007   46.859  135031164   2013.977305
# 1254       Puerto Rico  Americas  1982   73.750    3279001  10330.989150
# ...

# %%
df.to_csv("gab.csv")

# %%
# !pip install openpyxl

# %%
df.to_excel("gab.xlsx")

# %%
df.to_pickle("gab.pickle")

# %% [markdown]
# ### 읽기

# %%
# 인터넷에서 가져오기

pd.read_csv("https://raw.githubusercontent.com/kirenz/datasets/refs/heads/master/gapminder.csv")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
pd.read_csv('gab.csv')
# Out:
#       Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap
# 0              0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1              1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2              2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3              3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4              4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...          ...          ...       ...   ...      ...       ...         ...
# 1699        1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700        1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701        1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702        1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703        1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 7 columns]

# %%
pd.read_excel('gab.xlsx')
# Out:
#       Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap
# 0              0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1              1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2              2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3              3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4              4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...          ...          ...       ...   ...      ...       ...         ...
# 1699        1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700        1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701        1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702        1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703        1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 7 columns]

# %%
pd.read_excel('gab.xlsx', index_col = 1) # 인덱스 컬럼 1부터 읽기
# Out:
#              Unnamed: 0 continent  year  lifeExp       pop   gdpPercap
# country
# Afghanistan           0      Asia  1952   28.801   8425333  779.445314
# Afghanistan           1      Asia  1957   30.332   9240934  820.853030
# Afghanistan           2      Asia  1962   31.997  10267083  853.100710
# Afghanistan           3      Asia  1967   34.020  11537966  836.197138
# Afghanistan           4      Asia  1972   36.088  13079460  739.981106
# ...                 ...       ...   ...      ...       ...         ...
# Zimbabwe           1699    Africa  1987   62.351   9216418  706.157306
# Zimbabwe           1700    Africa  1992   60.377  10704340  693.420786
# Zimbabwe           1701    Africa  1997   46.809  11404948  792.449960
# Zimbabwe           1702    Africa  2002   39.989  11926563  672.038623
# Zimbabwe           1703    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
pd.read_pickle('df1.pickle')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### pickle

# %%
import pickle

# %%
data = {}
data = {'no' : 1, 'subject' : '안녕 피클', 'content' : '피클은 매우 간단합니다.'}
data
# Out:
# {'no': 1, 'subject': '안녕 피클', 'content': '피클은 매우 간단합니다.'}

# %%
# 피클 데이타 저장하기 

with open("data.pickle", 'wb') as f:
    pickle.dump(data, f)

# %%
# 저장한거 읽어오기

with open("data.pickle", "rb") as fr:
    df = pickle.load(fr)

df
# Out:
# {'no': 1, 'subject': '안녕 피클', 'content': '피클은 매우 간단합니다.'}

# %% [markdown]
# - df를 pickle 로 저장하기

# %%
df1 = df.sample(frac=0.01)

# %%
with open("df1.pickle", 'wb') as f:
    pickle.dump(df, f)

# %%
with open("df1.pickle", "rb") as fr:
    df = pickle.load(fr)

df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### 딕셔너리로 바꾸기 - jason 한다

# %%
df = pd.read_csv("data/gapminder.tsv", sep = '\t')
df.sample(frac = 0.01)
# Out:
#                     country continent  year  lifeExp        pop     gdpPercap
# 3               Afghanistan      Asia  1967   34.020   11537966    836.197138
# 1581                 Turkey    Europe  1997   68.835   63047647   6601.429915
# 980               Mauritius    Africa  1992   69.745    1096202   6058.253846
# 761                  Israel      Asia  1977   73.060    3495918  13306.619210
# 1298  Sao Tome and Principe    Africa  1962   51.893      65345   1071.551119
# 1131                Nigeria    Africa  1967   41.040   47287752   1014.514104
# 775                   Italy    Europe  1987   76.420   56729703  19207.234820
# 1065                Namibia    Africa  1997   58.909    1774766   3899.524260
# 1494                  Syria      Asia  1982   64.590    9410494   3761.837715
# 896                 Liberia    Africa  1992   40.802    1912974    636.622919
# 138                 Bolivia  Americas  1982   53.859    5642224   3156.510452
# ...

# %%
di = df[:2].to_dict()
di
# Out:
# {'country': {0: 'Afghanistan', 1: 'Afghanistan'},
#  'continent': {0: 'Asia', 1: 'Asia'},
#  'year': {0: 1952, 1: 1957},
#  'lifeExp': {0: 28.801, 1: 30.332},
#  'pop': {0: 8425333, 1: 9240934},
#  'gdpPercap': {0: 779.4453145, 1: 820.8530296}}

# %%
print(di)
# Out:
# {'country': {0: 'Afghanistan', 1: 'Afghanistan'}, 'continent': {0: 'Asia', 1: 'Asia'}, 'year': {0: 1952, 1: 1957}, 'lifeExp': {0: 28.801, 1: 30.332}, 'pop': {0: 8425333, 1: 9240934}, 'gdpPercap': {0: 779.4453145, 1: 820.8530296}}

# %%
# pretty print

import pprint
pprint.pprint(di)
# Out:
# {'continent': {0: 'Asia', 1: 'Asia'},
#  'country': {0: 'Afghanistan', 1: 'Afghanistan'},
#  'gdpPercap': {0: 779.4453145, 1: 820.8530296},
#  'lifeExp': {0: 28.801, 1: 30.332},
#  'pop': {0: 8425333, 1: 9240934},
#  'year': {0: 1952, 1: 1957}}

# %%
pd.DataFrame.from_dict(di)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %% [markdown]
# # 시각화
#
# ```
# - matplotlib
# - df
# - seaborn
#
# ```

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
df = sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# dataset 가 일번인 걸 찾고 싶다

df.query('dataset == "I" ')
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
dataset1 = df.query('dataset == "I" ')
dataset2 = df.query('dataset == "II" ')
dataset3 = df.query('dataset == "III" ')
dataset4 = df.query('dataset == "IV" ')

# %% [markdown]
# - 그림 그리는 라이브러리 설치

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset1 ['x'], dataset1 ['y'] )

# %%
plt.scatter(dataset1 ['x'], dataset1 ['y'] )

# %%
plt.scatter('x', 'y', data = dataset1)

# %%
plt.scatter('x', 'y', data = dataset2)

# %%
plt.scatter('x', 'y', data = dataset3)

# %%
plt.scatter('x', 'y', data = dataset4)

# %% [markdown]
# ## matplotlib

# %%
# 기본값은 직선

# plt.plot(dataset1[['x']])
# plt.plot('x', 'y', data = dataset1)
# plt.plot('x', 'y', data = dataset1)

# plt.plot('x', 'y', 'bo', data = dataset1) # bo = blue circle # ro = red circle
# plt.plot(dataset1['x'], 'r+')             # r+ = red plus

plt.plot(dataset1['y'], 'bo')
plt.plot(dataset1['y'])

## 그림은 살아있는 거 전부 표현 됨.

# %%
dataset1['x']
# Out:
# 0     10.0
# 1      8.0
# 2     13.0
# 3      9.0
# 4     11.0
# 5     14.0
# 6      6.0
# 7      4.0
# 8     12.0
# 9      7.0
# 10     5.0
# Name: x, dtype: float64

# %% [markdown]
# ### 하나의 figure 에 여러개의 ax 넣기

# %%
fig, ax = plt.subplots()
ax = plt.scatter('x', 'y', data = dataset1)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2) # 1행 2열 
# ax[0] = plt.scatter('x', 'y', data = dataset1)

ax[0].scatter('x', 'y', data = dataset1)
ax[1].plot(dataset1['y'], 'r')

# %%
plt.hist(df['x'])
# Out:
# (array([ 6.,  3., 16.,  3.,  6.,  3.,  6.,  0.,  0.,  1.]),
#  array([ 4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. , 17.5, 19. ]),
#  <BarContainer object of 10 artists>)

# %%
# 바 그래프
df_x = pd.DataFrame(df['x'].value_counts()).reset_index()

plt.bar(df_x['x'], df_x['count'])
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2) # 2행 2열 
# ax[0] = plt.scatter('x', 'y', data = dataset1)

ax[0][0].scatter('x', 'y', data = dataset1)
ax[0][1].plot(dataset1['y'], 'r')
ax[1][0].hist(df['x'])
ax[1][1].bar(df_x['x'], df_x['count'])
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ### df에서 바로 그리기
# ```
# - 여러개 그리기는 불가능
#
# ```

# %%
# df.plot(x = 'x')
# dataset1.plot("x")
# dataset1.plot("x", kind = 'hist')
# dataset1.plot("x", kind = 'box')
dataset1.plot("x", 'y', kind = 'scatter')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## 데이터프레임(df) 로 그리기

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg[:2]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
mpg['origin'] = mpg['origin'].astype("category")

# %%
mpg['name']
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 398, dtype: str

# %%
mpg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    category
#  8   name          398 non-null    str
# dtypes: category(1), float64(4), int64(3), str(1)
# memory usage: 25.4 KB

# %% [markdown]
# - 변수 1개, 숫자형 mpg , 문자형 name, 범주형 origin

# %%
mpg.plot( y='mpg' , kind = 'line')
# mpg.plot( y='name' , kind = 'line') not working
# mpg.plot( y='origin' , kind = 'line') not working
# Out:
# <Axes: >

# %% [markdown]
# - 변수 2개, 수치 + 수치, 수치 + 문자, 수지 + 범주

# %%
mpg.plot(x='displacement', y='mpg', kind='line')
# mpg.plot(x='displacement', y='origin', kind='line')
# Out:
# <Axes: xlabel='displacement'>

# %%
mpg[:2]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %% [markdown]
# ### bar 그래프

# %% [markdown]
# - 변수 1개

# %%
mpg.plot( y='mpg', kind='bar')
# mpg.plot( y='name', kind='bar')
# mpg.plot( y='origin', kind='line')
# Out:
# <Axes: >

# %% [markdown]
# - 변수 2개 . 수치+수치, 수치+문자, 수치+범주

# %%
# mpg.plot(x='displacement',  y='mpg', kind='bar' )
mpg.plot(y='displacement',  x='origin', kind='bar' )
# Out:
# <Axes: xlabel='origin'>

# %%
import pandas as pd
df2 = pd.DataFrame(mpg['origin'].value_counts())
df2
# Out:
#         count
# origin
# usa       249
# japan      79
# europe     70

# %%
mpg['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df2.plot(y='count', kind = 'bar')
# Out:
# <Axes: xlabel='origin'>

# %%
df2['count'].plot(kind = 'bar', rot = 0) # rot=0 은 글자를 가로로 눕힘
plt.show()

# %%
# 위에와 출력은 같지만 , 다른 방법
df2.plot(y='count', kind='bar', rot=0)
# Out:
# <Axes: xlabel='origin'>

# %%
df3 = df2.reset_index()
df3
# Out:
#    origin  count
# 0     usa    249
# 1   japan     79
# 2  europe     70

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
import numpy as np
df3.plot(kind='bar', x='origin', y='count', rot=0)
plt.title("제조국별 차량 모델수")
plt.yticks(np.arange(100, 500))
plt.show()

# %%
mpg.plot( y='mpg' , kind = 'bar')
# mpg.plot( y='name' , kind = 'bar)
# mpg.plot( y='origin' , kind = 'bar')
# Out:
# <Axes: >

# %%
mpg.plot(x='displacement', y='mpg', kind='bar')
# Out:
# <Axes: xlabel='displacement'>

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# 변수 1개, 수치형

sns.histplot(data = tips, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, str): ['Yes', 'No']

# %%
# 변수 1개, 범주형

sns.histplot(data = tips, x = 'smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='Count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
sns.histplot(data = tips, x ='total_bill', ax=ax[0])
sns.histplot(data = tips, x = 'smoker', ax=ax[1])

ax[0].set_title("총요금")
ax[1].set_title("흡연여부")
# plt.show()
# Out:
# Text(0.5, 1.0, '흡연여부')

# %%
# 변수 1개, 수치형

sns.kdeplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# # 변수 1개, 수치형
sns.rugplot(data=tips, x='total_bill' )

# # 변수 1개, 수치형
sns.kdeplot(data=tips, x='total_bill' )
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# #### 막대그래프 countplot(칼럼이 하나 일때), barplot (칼럼이 두개 일때)

# %%
tips[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(data=tips, x='smoker', palette='pastel')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4716\4272613738.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=tips, x='smoker', palette='pastel')
# <Axes: xlabel='smoker', ylabel='count'>

# %%
# set(list(tips['day']))
# set(tips['day'])
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, str): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.countplot(data=tips, x='day', hue='day', palette='viridis')
sns.countplot(data=tips, x='day', palette='viridis')
# hue ; 색상
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4716\3120245568.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=tips, x='day', palette='viridis')
# <Axes: xlabel='day', ylabel='count'>

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ### barplot
#
# - 범주형 + 수치형

# %%
tips[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.barplot(data=tips, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=tips, x = 'smoker', y = 'tip', palette='Set1') 

# 색상은 x 측 기준으로,,
# sns.barplot(data=tips, x = 'smoker', y = 'tip', estimator=max)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4716\1276238901.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x = 'smoker', y = 'tip', palette='Set1')
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(data=tips, x = 'day', y = 'tip', legend=False, palette='Set1')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4716\586963099.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x = 'day', y = 'tip', legend=False, palette='Set1')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=tips, x = 'day', y = 'smoker', legend=False, palette='Set1')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4716\1930496540.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x = 'day', y = 'smoker', legend=False, palette='Set1')
# <Axes: xlabel='day', ylabel='smoker'>

# %%
tips['tip']

# smoker 인 사람과 아닌 사람의 각각의 팁 평균은?

# tips [ tips['smoker'] == "Yes" ]

tips.query(' smoker == "Yes" ')['tip'].mean()
tips.query(' smoker == "No" ')['tip'].mean()
# Out:
# np.float64(2.9918543046357615)

# %%
tips.groupby('smoker')['tip'].mean()

# 위에 내용을 한줄로 하면
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %% [markdown]
# ### 산점도 scatterplot 그리기
# - 2차원
# - 수치 + 수치
# - 범주 + 수치

# %%
tips[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips, x = 'smoker', y = 'tip')
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.regplot(data = tips, x = 'total_bill', y = 'tip')

# 선을 회귀선이라고 한다. regression
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data = tips, x = 'total_bill', y = 'tip')

# %%
sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind='hex')

# %%
# sns.kdeplot(data= tips , x= 'total_bill') 
sns.kdeplot(data= tips , x= 'total_bill', y='tip', fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### boxplot

# %%
# 2차원 : 범주형 + 숫자형

# sns.boxplot(data=tips, x='smoker', y='tip')
sns.boxplot(data=tips, x='smoker', y='tip', hue='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
tips[:2]
tips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.boxplot(data=tips, x='size', y='tip', hue='size')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
tips[ 'size'] = tips[ 'size'].astype('category')

# %%
tips['size'].unique()
# Out:
# [2, 3, 4, 1, 6, 5]
# Categories (6, int64): [1, 2, 3, 4, 5, 6]

# %%
sns.boxplot(data=tips, x='size', y='tip', hue='size')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# - 다른 방법
# ```
# dia.info()
# len(dia)
# dia.shape[0] # 행의 개수
# dia.shape[1] # 열의 개수
#
# ```

# %%
dia = sns.load_dataset("diamonds")
dia

# dia 관측치 observations 개수? = 53940
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
dia[:3]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
# 각 컬럼에 해당하는 카테고리(목록)이 몇개인지 알고 싶을 때

dia['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, str): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
dia1 = dia.query('color == "D" or color == "E" ')
dia1[ 'color' ].astype('str').astype('category')
# Out:
# 34622    E
# 43696    D
# 28068    E
# 39780    D
# 28696    E
#         ..
# 43795    E
# 22780    D
# 30675    E
# 50286    D
# 5084     D
# Name: color, Length: 1682, dtype: category
# Categories (2, str): ['D', 'E']

# %%
# 산점도를 그려봅시다.
# 여러가지 색상 > 선택하기 전에 카테고리 먼저 체크 > 색상은 숫자 컬럼이 아닌 거.
# 1. 수치형 + 수치형
# sns.scatterplot(data = dia, x = 'carat', y = 'price')

# 1-1. 수치형 + 수치형, 수치형
# sns.scatterplot(data = dia, x = 'carat', y = 'price', hue='depth')

# 1-2. 수치형 + 수치형, 범주형
# sns.scatterplot(data = dia, x = 'carat', y = 'price', hue='cut')

#. 2. 범주형 + 수치형
# sns.scatterplot(data = dia, x = 'cut', y = 'price')

#. 2-1. 범주형 + 수치형, 수치형
# sns.scatterplot(data = dia, x = 'cut', y = 'price', hue='depth')

#. 2-2. 범주형 + 수치형, 범주형
# sns.scatterplot(data = dia, x = 'cut', y = 'price', hue='color')

#. 3. 범주형 + 범주형
# sns.scatterplot(data = dia, x = 'cut', y = 'color')

#. 4. 수치형 + 범주형
# sns.scatterplot(data = dia, x = 'price', y = 'cut')

#. 4-1. 수치형 + 범주형, 범주형
sns.scatterplot(data = dia1, x = 'cut', y = 'price', hue = 'color')

plt.show()

# %%
# 10% 만 추출해서 다시 dia 로 덮어쓰기

dia = sns.load_dataset("diamonds")
dia = dia.sample(frac=0.1, random_state=1234) # 0.1 보다 .1 로 0 을 생략해서 쓰기도 한다.
dia

# random_state > random seed 값 준거임
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 18197   1.57      Ideal     I     SI2   62.8   57.0   7385  7.39  7.36  4.63
# 34622   0.31    Premium     E     VS2   60.6   59.0    872  4.39  4.36  2.65
# 42495   0.51  Very Good     F     SI1   61.7   55.0   1320  5.14  5.16  3.18
# 40139   0.70       Fair     G      I1   64.6   59.0   1115  5.64  5.48  3.60
# 3872    0.90  Very Good     H     SI2   62.3   61.0   3481  6.15  6.17  3.84
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 5084    0.70      Ideal     D     VS1   61.4   54.2   3752  5.72  5.76  3.52
# 35835   0.42  Very Good     G     SI1   61.7   55.0    916  4.78  4.81  2.96
# 15140   1.12      Ideal     F     SI1   61.6   56.0   6087  6.66  6.72  4.12
# 5112    0.72      Ideal     F     VS1   61.5   56.0   3759  5.74  5.77  3.53
# 50469   0.71  Very Good     G     SI1   61.2   61.0   2266  5.66  5.71  3.48
#
# [5394 rows x 10 columns]

# %%
# 다시 그려보자.

sns.scatterplot(data = dia, x = 'carat', y = 'price', hue='cut')
plt.show()

# %%
# 가격이 7000 달러 이상인것만 출력.

plt.figure(figsize=(5, 5))
# 사이즈 

df = dia.query("price >= 7000")
sns.boxplot(data=df, x='color', y='price', hue='color', dodge=False)
# 색상 hue 뒤에 dodge=False 를 붙여주면 홀쭉하게 안나옴.

# plt.savefig('test.png', dpi=300)
# 이미지 파일 저장해서 쓰고 싶을 때
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
tips = sns.load_dataset('tips')
tips[:3]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# sns.barplot(data=tips, x='time', y='total_bi/ll')
# sns.barplot(data=tips, x='time', y='total_bill', hue = 'time')
sns.barplot(data=tips, x='time', y='total_bill', hue = 'time', dodge=False)
# sns.barplot(data=tips, x='time', y='total_bill', hue = 'sex')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
tips.query('time == "Lunch" ')['total_bill'].mean()
tips.query('time == "Dinner" ')['total_bill'].mean()
# Out:
# np.float64(20.79715909090909)

# %%
# sns.boxplot(data=tips, x = 'time', y = 'total_bill')
# sns.boxplot(data=tips, x = 'time', y = 'total_bill', hue='time', dodge=False)
sns.boxplot(data=tips, x = 'time', y = 'total_bill', hue='sex')
# sns.boxplot(data=tips, x = 'tip', y = 'total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips, x='time', y='total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(data=tips, x='time', y='total_bill')
sns.boxplot(data=tips, x='time', y='total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
sns.boxplot(data=tips, x='time', y= 'total_bill', hue='time', dodge=False, ax=ax[0])
ax[0].set_title("Box plot")
sns.violinplot(data=tips, x='time', y= 'total_bill', hue='time', dodge=False, ax=ax[1])
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(data=tips, hue='smoker')

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='smoker')
# sns.set_style("darkgrid")
plt.style.use("ggplot")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# !pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ------------ --------------------------- 11.5/37.3 MB 62.2 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/37.3 MB 62.5 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 62.8 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 56.1 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
# 교재 169

# plt.style.use('default')
# tips['tip'].plot(kind='hist')
# tips['tip'].plot.hist
# tips['tip'].plot(kind='kde')

tips['tip'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
tips.plot("total_bill", "tip", kind='scatter')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.plot.scatter("total_bill", "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.plot(kind='box')
# Out:
# <Axes: >

# %%
# 위에 셋중에 두가지만 하고 싶다.

tips[ ['tip', 'size'] ].plot(kind='box')
# Out:
# <Axes: >

# %%
# 위에 걸 SnS 으로 만들 때

sns.boxplot(data=tips[ ['tip', 'size']])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
np.random.seed(19680801)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm

plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
mpg = sns.load_dataset("mpg")
mpg[:2]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
# 산점도 만들기.

sns.scatterplot(data=mpg, x='mpg', y='horsepower', hue='origin')
# Out:
# <Axes: xlabel='mpg', ylabel='horsepower'>

# %%
import plotly.express as px
import plotly.io as pio

# %%
px.scatter(mpg, x='mpg', y='horsepower', color='origin')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_60.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# !pip list |findstr plotly

# !pip install plotly==5.5.0
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# ...
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/26.5 MB ? eta -:--:--
#    ----------- ---------------------------- 7.3/26.5 MB 59.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 14.7/26.5 MB 43.2 MB/s eta 0:00:01
#    ---------------------------------------  26.5/26.5 MB 49.8 MB/s eta 0:00:01
#    ---------------------------------------- 26.5/26.5 MB 43.5 MB/s  0:00:00
# ...
#
#   Attempting uninstall: plotly
#
#     Found existing installation: plotly 6.6.0
#
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#     Uninstalling plotly-6.6.0:
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
# ...

# %%
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
import plotly.express as px

fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_57.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## 그룹별로 묶기

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\pandas'

# %%
df = pd.read_csv("data/gapminder.tsv", sep='\t')
df[:2]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
# 가장 최근 년도는?

# max(df['year'])
# np.max(df['year'])

df['year'].max()  # 가장 선호!!
# Out:
# np.int64(2007)

# %%
# 2007 년치 Americas 대륙의  데이터를 뽑으면?

gap = df.query("year == 2007 & continent == 'Americas'")
gap
# Out:
#                   country continent  year  lifeExp        pop     gdpPercap
# 59              Argentina  Americas  2007   75.320   40301927  12779.379640
# 143               Bolivia  Americas  2007   65.554    9119152   3822.137084
# 179                Brazil  Americas  2007   72.390  190010647   9065.800825
# 251                Canada  Americas  2007   80.653   33390141  36319.235010
# 287                 Chile  Americas  2007   78.553   16284741  13171.638850
# 311              Colombia  Americas  2007   72.889   44227550   7006.580419
# 359            Costa Rica  Americas  2007   78.782    4133884   9645.061420
# 395                  Cuba  Americas  2007   78.273   11416987   8948.102923
# 443    Dominican Republic  Americas  2007   72.235    9319622   6025.374752
# 455               Ecuador  Americas  2007   74.994   13755680   6873.262326
# 479           El Salvador  Americas  2007   71.878    6939688   5728.353514
# ...

# %%
# 국가별 기대수명을 시각화 해주세요.

sns.barplot(data = gap, x = 'country', y = 'lifeExp')
plt.xticks(rotation = 45)
plt.show()

# %%
# 대륙별로 기대수명은?

df.groupby('continent')[['lifeExp']].mean()

# df.groupby('continent') > 컨티넌트만 모으기
# Out:
#              lifeExp
# continent
# Africa     48.865330
# Americas   64.658737
# Asia       60.064903
# Europe     71.903686
# Oceania    74.326208

# %%
# 위 공식을 풀어 쓴 코드

list(df.groupby('continent'))

for (i, _) in df.groupby('continent'):
    print(i)

df['lifeExp'].mean()
# Out:
# Africa
# Americas
# Asia
# Europe
# Oceania
# np.float64(59.474439366197174)

# %%
# 대륙별로 기대수명 평균은?
# df.groupby('continent').sum()
# 방법1
# df.groupby('continent')[['lifeExp', 'pop']].mean()

# 방법2
# df[['continent', 'lifeExp', 'pop']].groupby('continent')[['lifeExp', 'pop']].mean()

# 방법3
# df.groupby('continent').sum()[['lifeExp', 'pop']]

# %%
tips = sns.load_dataset('tips')

# %%
grouped = tips.groupby('time')

for i, j in grouped:
    print(i)
    print(j)
    print("-"*50)
# Out:
# Lunch
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1
# 223       15.98  3.00  Female     No   Fri  Lunch     3
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2
#
# [68 rows x 7 columns]
# --------------------------------------------------
# Dinner
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# ...

# %%
tips

# %%
tips = sns.load_dataset('tips')
tips.groupby('time')[['tip']].mean()
tips.groupby('time')[['tip', 'total_bill']].mean()
# Out:
#              tip  total_bill
# time
# Lunch   2.728088   17.168676
# Dinner  3.102670   20.797159

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# tips 에서 'day' 별로 tip 의 최대 값은?
tips.groupby('day')[['tip']].max()

# 'day' 별로 tip 과  total bill 의 최대값
tips.groupby('day')[['tip', 'total_bill']].max()

# # 성별로 tip 과 total bill 의 평균 값
tips.groupby('sex')[['tip', 'total_bill']].mean()

# # 인원수별로 tip 과 total bill 의 평균 값
tips.groupby('size')[['tip', 'total_bill']].mean()
# Out:
#            tip  total_bill
# size
# 1     1.437500    7.242500
# 2     2.582308   16.448013
# 3     3.393158   23.277632
# 4     4.135405   28.613514
# 5     4.028000   30.068000
# 6     5.225000   34.830000

# %%
# 하나의 변수로 그룹 만들기
tips = sns.load_dataset('tips')
tips.groupby('time')[['tip']].mean()
tips.groupby('time')[['tip', 'total_bill']].mean()
# Out:
#              tip  total_bill
# time
# Lunch   2.728088   17.168676
# Dinner  3.102670   20.797159

# %%
# 두개의 변수로 그룹 만들기 (요일별로 시간별로 )

tips = sns.load_dataset('tips')

tips.groupby(['day', 'time'])[['tip']].mean()
tips.groupby('time')[['tip', 'total_bill']].mean()
# Out:
#              tip  total_bill
# time
# Lunch   2.728088   17.168676
# Dinner  3.102670   20.797159

# %%
import numpy as np

# %%
# 인덱스를 칼럼으로 보내기
temp.unstack(lever=0)
temp1 = temp.unstsack(level=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # 인덱스를 칼럼으로 보내기
# ----> 2 temp.unstack(lever=0)
#       3 temp1 = temp.unstsack(level=1)
#
# NameError: name 'temp' is not defined

# %%
# 칼럼을 인덱스로 보내기
temp1.stack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 # 칼럼을 인덱스로 보내기
# ----> 2 temp1.stack()
#
# NameError: name 'temp1' is not defined

# %%
for i, _ in tips.groupby(['day', 'time']):
    print(i)
# Out:
# ('Thur', 'Lunch')
# ('Thur', 'Dinner')
# ('Fri', 'Lunch')
# ('Fri', 'Dinner')
# ('Sat', 'Dinner')
# ('Sun', 'Dinner')

# %%
for i, j in tips.groupby(['day', 'time']):
    print(i)
    print(j)
# Out:
# ('Thur', 'Lunch')
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 201       12.74  2.01  Female    Yes  Thur  Lunch     2
# 202       13.00  2.00  Female    Yes  Thur  Lunch     2
# 203       16.40  2.50  Female    Yes  Thur  Lunch     2
# 204       20.53  4.00    Male    Yes  Thur  Lunch     4
# 205       16.47  3.23  Female    Yes  Thur  Lunch     3
#
# [61 rows x 7 columns]
# ('Thur', 'Dinner')
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2
# ('Fri', 'Lunch')
#      total_bill   tip     sex smoker  day   time  size
# ...

# %%
tips.groupby('time')[['tip']].count()
tips.groupby('time')[['tip']].max()
# tips.groupby('time')[['tip']].apply(np.mean)

tips.groupby('time')[['tip']].mean()
tips.groupby('time')[['tip']].apply('mean')
tips.groupby('time')[['tip']].agg('mean')
# Out:
#              tip
# time
# Lunch   2.728088
# Dinner  3.102670

# %%
# # 두가지 통계 함수롤 적용하려면.

tips.groupby('time')[['tip', 'total_bill']].agg({'mean', 'sum'})
# Out:
#            tip           total_bill
#            sum      mean        sum       mean
# time
# Lunch   185.51  2.728088    1167.47  17.168676
# Dinner  546.07  3.102670    3660.30  20.797159

# %%
# 각 컬럼별로 다른 함수를 적용하려면

tips.groupby('time')[['tip', 'total_bill']].agg({'tip' : 'mean', 'total_bill' : 'sum'})
# Out:
#              tip  total_bill
# time
# Lunch   2.728088     1167.47
# Dinner  3.102670     3660.30

# %%
df = tips.groupby('time')[['tip']].mean().plot(y='tip', kind='bar')

# %%
# 흡연 여부에 따른 평균 팁 금액을 막대그래프로 그려주세요

tips.groupby('smoker')[['tip']].mean().plot(y='tip', kind='bar', color= ['pink', 'skyblue'])
# Out:
# <Axes: xlabel='smoker'>

# %%
data = tips.groupby('smoker')[['tip']].mean()

# %%
# sns 사용하기

sns.barplot(data = data, x = 'smoker', y = 'tip', hue = 'smoker', dodge=False, palette = 'pastel')
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %% [markdown]
# # 칼럼 이름 바꾸기

# %%
# total_bill 을 total 로 바꾸기

tips.rename( {"total_bill" : "total"}, axis = 1, inplace = True )
tips
# 덮어쓰기를 해줘야 바뀐다 !
# Out:
#      total   tip     sex smoker   day    time  size
# 0    16.99  1.01  Female     No   Sun  Dinner     2
# 1    10.34  1.66    Male     No   Sun  Dinner     3
# 2    21.01  3.50    Male     No   Sun  Dinner     3
# 3    23.68  3.31    Male     No   Sun  Dinner     2
# 4    24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...   ...     ...    ...   ...     ...   ...
# 239  29.03  5.92    Male     No   Sat  Dinner     3
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  17.82  1.75    Male     No   Sat  Dinner     2
# 243  18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 결측치 교재 287p ~

# %%
df = sns.load_dataset('titanic')
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
## 결측치 찾기

df.isnull().sum()  # 전체에서 찾기
df['age'].isnull().sum() # 원하는 칼럼에서만 찾기
# Out:
# np.int64(177)

# %%
## 결측치 처리하기

df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# df['age'].sum()/( df['age'].isnull().sum())
df['age'].sum()/(len(df) - df['age'].isnull().sum())
# Out:
# np.float64(29.69911764705882)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset('flights')
flights[:2]
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
flights.iloc[1,2]

# flights['passengers']['1']
# flights.loc[1, 'passengers']
# Out:
# np.int64(118)

# %%
flights.iloc[1,2] = 120
flights[:2]
# Out:
#    year month  passengers
# 0  1949   Jan       112.0
# 1  1949   Feb       120.0

# %% [markdown]
# ### 결측치로 바꾸기

# %%
# 결측치 (NAN) 으로 바꾸기

flights.iloc[1, 2] = np.nan
flights[:2]
# Out:
#    year month  passengers
# 0  1949   Jan       112.0
# 1  1949   Feb         NaN

# %%
# 390 짜리 passengers > 인덱스 142

flights.iloc[-2, 2] = np.nan
flights
# Out:
#      year month  passengers
# 0    1949   Jan       112.0
# 1    1949   Feb         NaN
# 2    1949   Mar       132.0
# 3    1949   Apr       129.0
# 4    1949   May       121.0
# ..    ...   ...         ...
# 139  1960   Aug       606.0
# 140  1960   Sep       508.0
# 141  1960   Oct       461.0
# 142  1960   Nov         NaN
# 143  1960   Dec       432.0
#
# [144 rows x 3 columns]

# %% [markdown]
# ### 결측지 개수 세기

# %%
# 데이셋에서 결측의 개수를 알고 싶을 때

# flights.info()

# flights.isnull().sum()

flights['passengers'].isnull().sum()
# Out:
# np.int64(2)

# %%
# 결측치 아닌거.. isnull 의 반대말

flights.notnull().sum()


# flights['passengers'].notnull().sum()
# Out:
# year          144
# month         144
# passengers    142
# dtype: int64

# %% [markdown]
# ### 결측치 처리하기

# %%
# 결측치 삭제하기
flights.dropna()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# 1. fillna()  fill + na

# 어떤 숫자로 대체하기
flights.fillna(0)
# Out:
#      year month  passengers
# 0    1949   Jan       112.0
# 1    1949   Feb         0.0
# 2    1949   Mar       132.0
# 3    1949   Apr       129.0
# 4    1949   May       121.0
# ..    ...   ...         ...
# 139  1960   Aug       606.0
# 140  1960   Sep       508.0
# 141  1960   Oct       461.0
# 142  1960   Nov         0.0
# 143  1960   Dec       432.0
#
# [144 rows x 3 columns]

# %%
# 평균으로 대체하기

avg = int(flights['passengers'].mean())
flights.fillna(avg)
# Out:
#      year month  passengers
# 0    1949   Jan       112.0
# 1    1949   Feb       280.0
# 2    1949   Mar       132.0
# 3    1949   Apr       129.0
# 4    1949   May       121.0
# ..    ...   ...         ...
# 139  1960   Aug       606.0
# 140  1960   Sep       508.0
# 141  1960   Oct       461.0
# 142  1960   Nov       280.0
# 143  1960   Dec       432.0
#
# [144 rows x 3 columns]

# %%
# 그룹별 평균으로 대체하기

flights.groupby('month')['passengers'].transform(lambda x: x.mean())

# flights.groupby('month')['passengers'].apply(lambda x: x.mean())
# Out:
# 0      241.750000
# 1      245.636364
# 2      270.166667
# 3      267.083333
# 4      271.833333
#           ...
# 139    351.083333
# 140    302.416667
# 141    266.583333
# 142    218.545455
# 143    261.833333
# Name: passengers, Length: 144, dtype: float64

# %%
# 2. ffill (forward fill)

# flights.fillna(method='ffill')
flights.ffill
# Out:
# <bound method NDFrame.ffill of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
# 3. bfill (backward fill)

# flights.fillna(method='bfill')
flights.bfill
# Out:
# <bound method NDFrame.bfill of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
# 4. interpolate ; 보간하다, (중간값을) 채우다

flights['passengers'].interpolate()
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %% [markdown]
# ### 이상치 outlier

# %% [markdown]
# #### 1. 이상치 찾기

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    str
#  8   name          398 non-null    str
# dtypes: float64(4), int64(3), str(2)
# memory usage: 28.1 KB

# %%
url = "https://raw.githubusercontent.com/youngwoos/Doit_Python/refs/heads/main/Data/mpg.csv"
mpg = pd.read_csv(url)
mpg.info()
mpg[:2]
mpg
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    str
#  1   model         234 non-null    str
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    str
#  6   drv           234 non-null    str
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    str
#  10  category      234 non-null    str
# dtypes: float64(1), int64(4), str(6)
# memory usage: 20.2 KB
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# ...

# %% [markdown]
# - 박스플롯을 그린다.

# %%
# 'cty' 의 박스플롯을 그려 주세요.

sns.boxplot(data=mpg, y='cty')

# 위에 동그라미가 이상치
# Out:
# <Axes: ylabel='cty'>

# %% [markdown]
# #### 2. 이상치 처리하기

# %%
# - 이상치 제외하기

# cty <= 26 뷰다 작은 데이터셋을 만들어주세요.

mpg_normal = mpg.query("cty <= @upper")
mpg_normal
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg_outlier = mpg.query("cty > 26.5")
mpg_outlier
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 99         honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category
# 99   subcompact
# 196     compact
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
# 박스 플롯의 정확한 값 구하기 ; IQR 구하기 InterQurtileRange

mpg['cty'].describe()
mpg['cty'].quantile(.75)
mpg['cty'].quantile(.25)

IQR = (mpg['cty'].quantile(.75) - mpg['cty'].quantile(.25))

upper = mpg['cty'].quantile(.75) + 1.5 * IQR  # 26.5 > 75% 지점이 위에 박스 라인
lower = mpg['cty'].quantile(.25) - 1.5 * IQR  # 6.5 > 25% 지점이 아래 박스 라인

# 선들은 수염이라고 함.

# %%
# manufacturer 제조사는 모두 몇개입니까?
len(mpg['manufacturer'].unique())
# Out:
# 15

# %%
# 시내 주행연비의 최대값, vudrbsdms?

mpg['cty'].max()
mpg['cty'].mean()
# Out:
# np.float64(16.858974358974358)

# %%
# 시내 주행연비의 최소인 제조사 이름은?

# mpg['cty'].min()
# mpg.query("cty == cty.min()")['manufacturer']

minimum = mpg['cty'].min()
mpg.query('cty == @minimum')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 59         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 126         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl category
# 54    12  e   pickup
# 59    12  e      suv
# 65    12  e   pickup
# 69    12  e   pickup
# 126   12  e      suv

# %% [markdown]
# ## 구간 나누기

# %%
data = pd.DataFrame(np.random.randint(1, 30, 100), columns = ['점수'])

# %%
# 1 ~ 10 : "C"
# 11 ~ 20 : "B"
# 21 ~ 30 : "A"

# %%
# 1) pd.cut() ; 제일 많이 쓰여지는 거 - 동일한 길이 - 
x = np.random.randint(0, 31, 100)
pd.cut(x, 3)
# cut_a = pd.cut(x, 3)
# cut_a.value_counts()

cat = pd.cut(x, 3)
cat.codes
cat=cat.rename_categories(['A', 'B', 'C'])
pd.DataFrame({'점수' : x, "등급" : cat.codes})

pd.cut(x, 3, labels = ['A', 'B', 'C'])
# Out:
# ['B', 'B', 'C', 'B', 'C', ..., 'A', 'B', 'B', 'A', 'B']
# Length: 100
# Categories (3, str): ['A' < 'B' < 'C']

# %%
tips
tips['tip'].max()

pd.cut(tips['tip'], 3, labels = ['A', 'B', 'C'])

tips['등급'] = pd.cut(tips['tip'], 3, labels = ['A', 'B', 'C'])

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_rate 등급
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673  A
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159  A
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734  A
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041  A
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765  A
# ..          ...   ...     ...    ...   ...     ...   ...        ... ..
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697  B
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352  A
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232  A
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426  A
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441  A
#
# [244 rows x 9 columns]

# %%
# 내가 값을 정해서 범주를 나누고 싶을 때,

tips['등급'] = pd.cut(tips['tip'], bins=[0, 2, 8, 15], labels = ['A', 'B', 'C'])
tips['등급'].value_counts()
pd.cut
# Out:
# <function pandas.cut(x, bins, right: 'bool' = True, labels=None, retbins: 'bool' = False, precision: 'int' = 3, include_lowest: 'bool' = False, duplicates: 'str' = 'raise', ordered: 'bool' = True)>

# %%
# 2) pd.qcut

pd.qcut(x, 3)
pd.qcut(x, 3).value_counts()
tips['등급'] = pd.qcut(tips['tip'], 3, labels = ['A', 'B', 'C'])
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_rate 등급
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673  A
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159  A
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734  C
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041  C
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765  C
# ..          ...   ...     ...    ...   ...     ...   ...        ... ..
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697  C
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352  A
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232  A
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426  A
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441  B
#
# [244 rows x 9 columns]

# %%
# 3) np.where (조건, 참, 거짓)

x = np.array([1, 2, 3, 4])
np.where(x > 3, 'Yes', 'No')
# Out:
# array(['No', 'No', 'No', 'Yes'], dtype='<U3')

# %%
tips = sns.load_dataset('tips')
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
np.where(tips['tip'] > 5, "Good", "Bad")
tips['평가'] = np.where(tips['tip'] > 5, "Good", "Bad")

# %%
tips['평가'] = np.where(tips['tip'] < 4, "나빠요", np.where(tips['tip'] < 8, '그럭저럭', "좋아요") )
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size    평가
# 0         16.99  1.01  Female     No   Sun  Dinner     2   나빠요
# 1         10.34  1.66    Male     No   Sun  Dinner     3   나빠요
# 2         21.01  3.50    Male     No   Sun  Dinner     3   나빠요
# 3         23.68  3.31    Male     No   Sun  Dinner     2   나빠요
# 4         24.59  3.61  Female     No   Sun  Dinner     4   나빠요
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  그럭저럭
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   나빠요
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   나빠요
# 242       17.82  1.75    Male     No   Sat  Dinner     2   나빠요
# 243       18.78  3.00  Female     No  Thur  Dinner     2   나빠요
#
# [244 rows x 8 columns]

# %%
mpg[:3]
mpg['model'][:20]
mpg['model'][:50]
# Out:
# 0                     a4
# 1                     a4
# 2                     a4
# 3                     a4
# 4                     a4
# 5                     a4
# 6                     a4
# 7             a4 quattro
# 8             a4 quattro
# 9             a4 quattro
# 10            a4 quattro
# 11            a4 quattro
# 12            a4 quattro
# 13            a4 quattro
# 14            a4 quattro
# 15            a6 quattro
# 16            a6 quattro
# 17            a6 quattro
# 18    c1500 suburban 2wd
# 19    c1500 suburban 2wd
# 20    c1500 suburban 2wd
# 21    c1500 suburban 2wd
# 22    c1500 suburban 2wd
# 23              corvette
# 24              corvette
# 25              corvette
# 26              corvette
# 27              corvette
# 28       k1500 tahoe 4wd
# 29       k1500 tahoe 4wd
# 30       k1500 tahoe 4wd
# 31       k1500 tahoe 4wd
# 32                malibu
# 33                malibu
# 34                malibu
# 35                malibu
# 36                malibu
# ...

# %%
mpg.query('model == "malibu" ')
# Out:
#    manufacturer   model  displ  year  cyl     trans drv  cty  hwy fl category
# 32    chevrolet  malibu    2.4  1999    4  auto(l4)   f   19   27  r  midsize
# 33    chevrolet  malibu    2.4  2008    4  auto(l4)   f   22   30  r  midsize
# 34    chevrolet  malibu    3.1  1999    6  auto(l4)   f   18   26  r  midsize
# 35    chevrolet  malibu    3.5  2008    6  auto(l4)   f   18   29  r  midsize
# 36    chevrolet  malibu    3.6  2008    6  auto(s6)   f   17   26  r  midsize

# %%
# mpg.query('model == "k1500" ') 검색하면 안 나오는데, 이렇게 이름 중 일부만 기어할 때 찾는 법

# mpg[mpg['model'].str.contains("k1500")]
# mpg[mpg['model'].str.contains("tahoe")]
mpg[mpg['model'].str.startswith("k1500")]
mpg[mpg['model'].str.endswith("4wd")]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 28     chevrolet    k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   14
# 29     chevrolet    k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 30     chevrolet    k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4   11
# 31     chevrolet    k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4   14
# 48         dodge  dakota pickup 4wd    3.7  2008    6  manual(m6)   4   15
# ..           ...                ...    ...   ...  ...         ...  ..  ...
# 202       toyota  toyota tacoma 4wd    2.7  2008    4  manual(m5)   4   17
# 203       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4   15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6    auto(l4)   4   15
# 205       toyota  toyota tacoma 4wd    4.0  2008    6  manual(m6)   4   15
# 206       toyota  toyota tacoma 4wd    4.0  2008    6    auto(l5)   4   16
#
#      hwy fl category
# 28    19  r      suv
# 29    14  e      suv
# ...

# %%
pd.read_csv("./data/gapminder.tsv", sep='\t')

# 우리나라가 있나?
gap = pd.read_csv("./data/gapminder.tsv", sep='\t')
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gap['country'].unique()
# Out:
# <StringArray>
# [       'Afghanistan',            'Albania',            'Algeria',
#              'Angola',          'Argentina',          'Australia',
#             'Austria',            'Bahrain',         'Bangladesh',
#             'Belgium',
#  ...
#              'Uganda',     'United Kingdom',      'United States',
#             'Uruguay',          'Venezuela',            'Vietnam',
#  'West Bank and Gaza',        'Yemen, Rep.',             'Zambia',
#            'Zimbabwe']
# Length: 142, dtype: str

# %%
gap['country'] = gap['country'].str.replace("Afghanistan", "Afghan")
gap
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0       Afghan      Asia  1952   28.801   8425333  779.445314
# 1       Afghan      Asia  1957   30.332   9240934  820.853030
# 2       Afghan      Asia  1962   31.997  10267083  853.100710
# 3       Afghan      Asia  1967   34.020  11537966  836.197138
# 4       Afghan      Asia  1972   36.088  13079460  739.981106
# ...        ...       ...   ...      ...       ...         ...
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gap['country'] = gap['country'].str.replace("Korea, Rep.", "South Korea")
gap['country'] = gap['country'].str.replace("Korea, Dem. Rep.", "North Korea")

korea = gap[gap['country'].str.contains("Korea")]

# %%
# 연도별(y) 로  lifeExp (x) 선 그래프 그리기.

# korea['year'].astype('datetime64[ns]')
korea['year'] = pd.to_datetime(korea['year'])

korea.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 828 to 851
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    24 non-null     str
#  1   continent  24 non-null     str
#  2   year       24 non-null     datetime64[ns]
#  3   lifeExp    24 non-null     float64
#  4   pop        24 non-null     int64
#  5   gdpPercap  24 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), str(2)
# memory usage: 1.3 KB

# %%
# sns.lineplot(data=korea.query('country == "South Korea" '), x = 'year', y = 'lifeExp')
# sns.lineplot(data=korea.query('country == "North Korea" '), x = 'year', y = 'lifeExp')

sns.lineplot(data=korea, x = 'year', y = 'lifeExp', hue = 'country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
korea.query('country == "South Korea" ').plot(x = 'year', y = 'lifeExp')
korea.query('country == "North Korea" ').plot(x = 'year', y = 'lifeExp')
# Out:
# <Axes: xlabel='year'>

# %%
import datetime

# %%
t1 = datetime.datetime.now()

# %%
t2 = datetime.datetime.now()

delta = t2 - t1

# delta = 차이

# %%
type(t1)
# Out:
# datetime.datetime

# %%
type(t2 - t1)
# Out:
# datetime.timedelta

# %%
t1.year
t1.month
t1.day
t1.hour
t1.minute
# Out:
# 38

# %%
chrismas = datetime.datetime(2026, 12, 25)
days = chrismas - datetime.datetime.now()

# %%
days.seconds/60/60
# Out:
# 13.248333333333333

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ebola = pd.read_csv('./data/country_timeseries.csv', parse_dates=[''])
ebola.info()
ebola[:2]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    str
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# #### datetime 객체로 바꾸기

# %%
pd.to_datetime(ebola['Date'])
ebola['Date'] = ebola['Date'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
t1 = '2015/01/05'
t2 = '2015-01-05'
t3 = '2015/01-05'
t4 = '2015.1.5'
t5 = '01/05/2015'
t6 = '13/05/2015'

pd.to_datetime(t5)
pd.to_datetime(t5, dayfirst = True)
pd.to_datetime(t5, format = '%d/%m/%Y')

# pd.to_datetime(t1)
# pd.to_datetime(t2)
# pd.to_datetime(t3)
# pd.to_datetime(t4)
# pd.to_datetime(t5)
# pd.to_datetime(t6)
# Out:
# Timestamp('2015-05-01 00:00:00')

# %%
# 연월일 분리하기

ebola = pd.read_csv('./data/country_timeseries.csv')

# %%
pd.to_datetime(ebola['Date'])
ebola['year'] = pd.to_datetime(ebola['Date']).dt.year
ebola['year']

# pd.to_datetime(ebola['Date']).dt.month
# ebola['month']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2014
#        ...
# 117    2014
# 118    2014
# 119    2014
# 120    2014
# 121    2014
# Name: year, Length: 122, dtype: int32

# %% [markdown]
# #### 교재 361p 시간 간격 계산하기

# %%
ebola['Date'] = pd.to_datetime(ebola['Date'])
ebola['Date'].max() - ebola['Date'].min()
# Out:
# Timedelta('289 days 00:00:00')

# %%
#### 교재 371p 시간별 데이터 추출하기

# 1. 데이터 불러오기
ebola = pd.read_csv('./data/country_timeseries.csv')

# 2. 날짜 컬럼을 진짜 '날짜 타입'으로 바꿔서 다시 저장하기 (중요!)
ebola['Date'] = pd.to_datetime(ebola['Date'])

# 3. 날짜 컬럼을 인덱스로 설정하기
ebola = ebola.set_index('Date')

# 3. 인덱스 설정 및 정렬 (슬라이싱을 위한 필수 단계!)
ebola = ebola.set_index('Date').sort_index()

# 4. 이제 안전하게 슬라이싱
ebola.loc['2014-01' : '2014-03']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 13
#      10 ebola = ebola.set_index('Date')
#      12 # 3. 인덱스 설정 및 정렬 (슬라이싱을 위한 필수 단계!)
# ---> 13 ebola = ebola.set_index('Date').sort_index()
#      15 # 4. 이제 안전하게 슬라이싱
#      16 ebola.loc['2014-01' : '2014-03']
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6977, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6974                 missing.append(col)
#    6976 if missing:
# -> 6977     raise KeyError(f"None of {missing} are in the columns")
#    6979 if inplace:
#    6980     frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %% [markdown]
# #### 교재 196 df.apply()

# %%
pip install --upgrade plotly
# Out:
# ...
#   Using cached plotly-6.6.0-py3-none-any.whl.metadata (8.5 kB)
# ...
# Using cached plotly-6.6.0-py3-none-any.whl (9.9 MB)
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
df = px.data.gapminder()
df = df[['year', 'lifeExp', 'pop']]
df
# Out:
#       year  lifeExp       pop
# 0     1952   28.801   8425333
# 1     1957   30.332   9240934
# 2     1962   31.997  10267083
# 3     1967   34.020  11537966
# 4     1972   36.088  13079460
# ...    ...      ...       ...
# 1699  1987   62.351   9216418
# 1700  1992   60.377  10704340
# 1701  1997   46.809  11404948
# 1702  2002   39.989  11926563
# 1703  2007   43.487  12311143
#
# [1704 rows x 3 columns]

# %%
df.mean()
# Out:
# year       1.979500e+03
# lifeExp    5.947444e+01
# pop        2.960121e+07
# dtype: float64

# %%
df['year'].apply('mean')
# Out:
# np.float64(1979.5)

# %%
df.apply('mean')
# Out:
# year       1.979500e+03
# lifeExp    5.947444e+01
# pop        2.960121e+07
# dtype: float64

# %% [markdown]
# ## tidy data 교재 178

# %%
df = pd.read_csv("./data/pew.csv")

# %%
df.columns
df.info()
df.iloc[:, :5]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   religion            18 non-null     str
#  1   <$10k               18 non-null     int64
#  2   $10-20k             18 non-null     int64
#  3   $20-30k             18 non-null     int64
#  4   $30-40k             18 non-null     int64
#  5   $40-50k             18 non-null     int64
#  6   $50-75k             18 non-null     int64
#  7   $75-100k            18 non-null     int64
#  8   $100-150k           18 non-null     int64
#  9   >150k               18 non-null     int64
#  10  Don't know/refused  18 non-null     int64
# dtypes: int64(10), str(1)
# memory usage: 1.7 KB
#                    religion  <$10k  $10-20k  $20-30k  $30-40k
# 0                  Agnostic     27       34       60       81
# 1                   Atheist     12       27       37       52
# ...

# %%
melted = df.melt(id_vars = 'religion')
melted
# Out:
#                   religion            variable  value
# 0                 Agnostic               <$10k     27
# 1                  Atheist               <$10k     12
# 2                 Buddhist               <$10k     27
# 3                 Catholic               <$10k    418
# 4       Don’t know/refused               <$10k     15
# ..                     ...                 ...    ...
# 175               Orthodox  Don't know/refused     73
# 176        Other Christian  Don't know/refused     18
# 177           Other Faiths  Don't know/refused     71
# 178  Other World Religions  Don't know/refused      8
# 179           Unaffiliated  Don't know/refused    597
#
# [180 rows x 3 columns]

# %%
melted['variable'][:50]
# Out:
# 0       <$10k
# 1       <$10k
# 2       <$10k
# 3       <$10k
# 4       <$10k
# 5       <$10k
# 6       <$10k
# 7       <$10k
# 8       <$10k
# 9       <$10k
# 10      <$10k
# 11      <$10k
# 12      <$10k
# 13      <$10k
# 14      <$10k
# 15      <$10k
# 16      <$10k
# 17      <$10k
# 18    $10-20k
# 19    $10-20k
# 20    $10-20k
# 21    $10-20k
# 22    $10-20k
# 23    $10-20k
# 24    $10-20k
# 25    $10-20k
# 26    $10-20k
# 27    $10-20k
# 28    $10-20k
# 29    $10-20k
# 30    $10-20k
# 31    $10-20k
# 32    $10-20k
# 33    $10-20k
# 34    $10-20k
# 35    $10-20k
# 36    $20-30k
# 37    $20-30k
# 38    $20-30k
# 39    $20-30k
# 40    $20-30k
# 41    $20-30k
# 42    $20-30k
# 43    $20-30k
# 44    $20-30k
# 45    $20-30k
# 46    $20-30k
# 47    $20-30k
# 48    $20-30k
# 49    $20-30k
# Name: variable, dtype: str

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                  'C': {0: 2, 1: 4, 2: 6},
                  'D': {0: 20, 1: 40, 2: 60}})


df
# Out:
#    A  B  C   D
# 0  a  1  2  20
# 1  b  3  4  40
# 2  c  5  6  60

# %%
df.melt(id_vars = 'A')  # 기준을 정해주는 거. 기준은 변하지 않는다.

melted = df.melt(id_vars = 'A', value_vars = ['B', 'C']) # value var 에 적지 않으면 날라감. 원하는 것 만 적을 수 있음.

# %% [markdown]
# - 컬럼 이름 바꾸기.

# %%
melted.columns = ['A', 'Category', '값']
melted
# Out:
#    A Category  값
# 0  a        B  1
# 1  b        B  3
# 2  c        B  5
# 3  a        C  2
# 4  b        C  4
# 5  c        C  6

# %%
melted.rename({'variable' : "카테고리", 'value' : "값"}, axis = 1)
# Out:
#    A Category  값
# 0  a        B  1
# 1  b        B  3
# 2  c        B  5
# 3  a        C  2
# 4  b        C  4
# 5  c        C  6

# %% [markdown]
# - 만들면서 컬럼 이름 정해주기

# %%
melted = df.melt(id_vars = 'A', value_vars = ['B', 'C'],
                 var_name = "카테고리", value_name = '값')

melted
# Out:
#    A 카테고리  값
# 0  a    B  1
# 1  b    B  3
# 2  c    B  5
# 3  a    C  2
# 4  b    C  4
# 5  c    C  6

# %%
# 이렇게도 된다.

melted = df.melt(id_vars = ['A', 'D'], value_vars = ['B', 'C'],
                 var_name = "카테고리", value_name = '값')

melted
# Out:
#    A   D 카테고리  값
# 0  a  20    B  1
# 1  b  40    B  3
# 2  c  60    B  5
# 3  a  20    C  2
# 4  b  40    C  4
# 5  c  60    C  6

# %%
melted = df.melt(id_vars= "A", value_vars=["B", "C"])

melted.pivot(index = 'A', columns = ['variable'], values = ['value'])
# Out:
#          value
# variable     B  C
# A
# a            1  2
# b            3  4
# c            5  6

# %%
tips = sns.load_dataset('tips')

# %%
tips.pivot(columns = 'smoker', values = 'tip')
# Out:
# smoker  Yes    No
# 0       NaN  1.01
# 1       NaN  1.66
# 2       NaN  3.50
# 3       NaN  3.31
# 4       NaN  3.61
# ..      ...   ...
# 239     NaN  5.92
# 240     2.0   NaN
# 241     2.0   NaN
# 242     NaN  1.75
# 243     NaN  3.00
#
# [244 rows x 2 columns]

# %%
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gap = px.data.gapminder()

# year 칼럼을 pivot 해주세요.

# gap.pivot(index = 'country', columns = 'year', values = 'gdpPercap')
gap.pivot_table(index = 'country', columns = 'continent', values = 'gdpPercap', aggfunc = 'sum')
# Out:
# continent                 Africa       Americas          Asia        Europe  \
# country
# Afghanistan                  NaN            NaN   9632.095181           NaN
# Albania                      NaN            NaN           NaN  39064.399592
# Algeria             53112.311678            NaN           NaN           NaN
# Angola              43285.206346            NaN           NaN           NaN
# Argentina                    NaN  107466.645392           NaN           NaN
# ...                          ...            ...           ...           ...
# Vietnam                      NaN            NaN  12212.551382           NaN
# West Bank and Gaza           NaN            NaN  45119.961375           NaN
# Yemen, Rep.                  NaN            NaN  18831.296066           NaN
# Zambia              16298.392908            NaN           NaN           NaN
# Zimbabwe             7630.296508            NaN           NaN           NaN
#
# continent           Oceania
# country
# ...

# %%
# 1952만 골라내서 적당한 칼럼 이름을 써서 pivot 하기

df = gap.query('year == 1952 ')
df

df.pivot_table(index = 'country', columns = 'continent', values = 'gdpPercap')
# Out:
# continent                Africa     Americas         Asia       Europe  \
# country
# Afghanistan                 NaN          NaN   779.445314          NaN
# Albania                     NaN          NaN          NaN  1601.056136
# Algeria             2449.008185          NaN          NaN          NaN
# Angola              3520.610273          NaN          NaN          NaN
# Argentina                   NaN  5911.315053          NaN          NaN
# ...                         ...          ...          ...          ...
# Vietnam                     NaN          NaN   605.066492          NaN
# West Bank and Gaza          NaN          NaN  1515.592329          NaN
# Yemen, Rep.                 NaN          NaN   781.717576          NaN
# Zambia              1147.388831          NaN          NaN          NaN
# Zimbabwe             406.884115          NaN          NaN          NaN
#
# continent           Oceania
# country
# Afghanistan             NaN
# Albania                 NaN
# ...

# %% [markdown]
# # 데이터 결합하고 분해하기

# %% [markdown]
# ## 데이터 병합하기

# %%
# merge - how > 메인 / on > 기준

# %%
# df.sort_values
# df.rename(colums = {'y' : 'year'})
# df.reset_index()

# %%
import pandas as pd

person = pd.read_csv("./data/survey_person.csv")
site = pd.read_csv("./data/survey_site.csv")
survey = pd.read_csv("./data/survey_survey.csv")
visited = pd.read_csv("./data/survey_visited.csv")

# %%
person[:2]
site[:2]
# survey[:2]
# visited[:2]
# Out:
#    name    lat    long
# 0  DR-1 -49.85 -128.57
# 1  DR-3 -47.15 -126.72

# %%
# pd.melt(df, ) = df.melt()

# pd.merge(site, visited, )

visited1 = visited.iloc[[0, 2, 6], : ]
visited1
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
site.merge(visited1, left_on = 'name', right_on = 'site')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
site.merge(visited, left_on = 'name', right_on = 'site')

# %%
df1 = pd.DataFrame({'key': ['a', 'a', 'b', 'b', 'c', 'c','d', 'd'],
                    'data1': range(8)})

df1
# Out:
#   key  data1
# 0   a      0
# 1   a      1
# 2   b      2
# 3   b      3
# 4   c      4
# 5   c      5
# 6   d      6
# 7   d      7

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd', 'e'],
                    'data2': range(4)})

df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2
# 3   e      3

# %%
# df1 = pd.DataFrame({'a':['a0','a1','a2'],
#                    'b':['b0','b1','b2'],
#                    'c':['c0','c1','c2']},
#                   index = [0,1,2])

# df2 = pd.DataFrame({'b':['b2','b3','b4'],
#                    'c':['c2','c3','c4'],
#                    'd':['d2','d3','d4']},
#                    index = [1,2,3])


# E = pd.Series(['e0','e1','e2','e3'], name = 'e')
# F = pd.Series(['f0','f1','f2'], name = 'f', index = [3,4,5])
# G = pd.Series(['g0','g1','g2','g3'], name = 'g')

# %% [markdown]
# # 복지 패널 데이터
# ```
# - https://github.com/youngwoos/Doit_Python/blob/main/Notebook/09.ipynb 참고
# ```

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !pip install pyreadstat
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 28.9 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
raw_welfare =  pd.read_spss("./data/Koweps_hpwc14_2019_beta2.sav")
raw_welfare
# Out:
#        h14_id  h14_ind  h14_sn  h14_merkey  h_new  h14_cobf   p14_wsc  \
# 0         2.0      1.0     1.0     20101.0    0.0       NaN  0.291589
# 1         3.0      1.0     1.0     30101.0    0.0       NaN  0.419753
# 2         4.0      1.0     1.0     40101.0    0.0       NaN  0.265263
# 3         6.0      1.0     1.0     60101.0    0.0       NaN  0.494906
# 4         6.0      1.0     1.0     60101.0    0.0       NaN  1.017935
# ...       ...      ...     ...         ...    ...       ...       ...
# 14413  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14414  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14415  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14416  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14417  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
#
#         p14_wsl      p14_wgc      p14_wgl  ...  wc14_64  wc14_65  wc14_5aq4  \
# ...

# %%
welfare = raw_welfare.copy()

# %%
welfare.shape
# Out:
# (14418, 830)

# %%
welfare.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Columns: 830 entries, h14_id to h14_pers_income5
# dtypes: float64(826), str(4)
# memory usage: 91.3 MB

# %%
welfare.describe() # 요약 통계량
# Out:
#              h14_id       h14_ind        h14_sn    h14_merkey         h_new  \
# count  14418.000000  14418.000000  14418.000000  1.441800e+04  14418.000000
# mean    4672.108406      3.121723      1.004855  4.672140e+07      0.201484
# std     2792.998128      3.297963      0.143205  2.793014e+07      0.401123
# min        2.000000      1.000000      1.000000  2.010100e+04      0.000000
# 25%     2356.000000      1.000000      1.000000  2.356030e+07      0.000000
# 50%     4535.000000      1.000000      1.000000  4.535010e+07      0.000000
# 75%     6616.000000      7.000000      1.000000  6.616010e+07      0.000000
# max     9800.000000     14.000000      9.000000  9.800070e+07      1.000000
#
#          h14_cobf       p14_wsc       p14_wsl       p14_wgc       p14_wgl  \
# count  121.000000  11513.000000  11513.000000  11513.000000  11513.000000
# mean     2.256198      1.000000      1.000000   4484.952219   4484.952541
# ...

# %%
welfare = welfare[['h14_g3', 'h14_g4', 'h14_g10', 'h14_g11', 'p1402_8aq1', 'h14_eco9', 'h14_reg7']]

# %%
welfare.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   h14_g3      14418 non-null  float64
#  1   h14_g4      14418 non-null  float64
#  2   h14_g10     14418 non-null  float64
#  3   h14_g11     14418 non-null  float64
#  4   p1402_8aq1  4534 non-null   float64
#  5   h14_eco9    6878 non-null   float64
#  6   h14_reg7    14418 non-null  float64
# dtypes: float64(7)
# memory usage: 788.6 KB

# %%
welfare.describe()
# Out:
#              h14_g3        h14_g4       h14_g10       h14_g11   p1402_8aq1  \
# count  14418.000000  14418.000000  14418.000000  14418.000000  4534.000000
# mean       1.548828   1969.280205      1.764184      1.542031   268.455007
# std        0.497627     24.402250      1.613871      0.498248   198.021206
# min        1.000000   1907.000000      0.000000      1.000000     0.000000
# 25%        1.000000   1948.000000      1.000000      1.000000   150.000000
# 50%        2.000000   1968.000000      1.000000      2.000000   220.000000
# 75%        2.000000   1990.000000      2.000000      2.000000   345.750000
# max        2.000000   2018.000000      6.000000      2.000000  1892.000000
#
#          h14_eco9      h14_reg7
# count  6878.00000  14418.000000
# mean    587.54827      3.730684
# std     264.23507      2.049151
# min     111.00000      1.000000
# 25%     313.00000      2.000000
# 50%     611.00000      3.000000
# 75%     873.00000      5.000000
# ...

# %%
welfare = welfare.rename(columns = {'sex' : 'gender',
                                    'h14_g4' : 'birth',
                                    'h14_g10' : 'marriage_type',
                                    'h14_g11' : 'religion',
                                    'p1402_8aq1' : 'income',
                                    'h14_eco9' : 'code_job',
                                    'h14_reg7' : 'code_region'})

welfare
# Out:
#        gender   birth  marriage_type  religion  income  code_job  code_region
# 0         2.0  1945.0            2.0       1.0     NaN       NaN          1.0
# 1         1.0  1948.0            2.0       2.0     NaN       NaN          1.0
# 2         1.0  1942.0            3.0       1.0   107.0     762.0          1.0
# 3         1.0  1962.0            1.0       1.0   192.0     855.0          1.0
# 4         2.0  1963.0            1.0       1.0     NaN       NaN          1.0
# ...       ...     ...            ...       ...     ...       ...          ...
# 14413     2.0  1967.0            1.0       1.0     NaN       NaN          5.0
# 14414     2.0  1992.0            5.0       1.0     NaN       NaN          5.0
# 14415     1.0  1995.0            5.0       1.0     NaN     910.0          5.0
# 14416     2.0  1998.0            5.0       1.0   200.0     246.0          5.0
# 14417     1.0  2001.0            0.0       1.0     NaN       NaN          5.0
#
# [14418 rows x 7 columns]

# %%
welfare['gender'].value_counts()
# Out:
# gender
# 2.0    7913
# 1.0    6505
# Name: count, dtype: int64

# %% [markdown]
# # 지도 시각화

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# plt.rc("font", family = 'malgun Gothic')

# %%
# pd.read_csv("")
# pd.read_xlsx("")
# pd.read_spss("")

df = pd.read_clipboard()
df

# 클립보드로 가져올 때는 읽어오기 전에 해당 내용을 복사 ctrl+c 해야 함
# Out:
#                대학교         위도          경도
# 0     KAIST 서울캠퍼스   37.592573  127.046737
# 1            KC대학교  37.548345  126.854797
# 2     가톨릭대학교(성신교정)  37.585922  127.004328
# 3     가톨릭대학교(성의교정)  37.499623  127.006065
# 4         감리교신학대학교  37.567645  126.961610
# 5            건국대학교  37.540762  127.079343
# 6     경기대학교 서울캠퍼스   37.300485  127.035833
# 7     경희대학교 서울캠퍼스   37.596195  127.052544
# 8            고려대학교  33.847782 -117.977748
# 9            광운대학교  37.619496  127.059696
# 10           국민대학교  37.609641  126.997697
# 11         덕성여자대학교  37.651199  127.016160
# 12           동국대학교  37.557477  127.002052
# 13         동덕여자대학교  37.606320  127.041808
# 14    명지대학교 서울캠퍼스   37.580205  126.923445
# 15           삼육대학교  37.642952  127.105476
# 16    상명대학교 서울캠퍼스   37.602638  126.955252
# 17           서강대학교  37.550944  126.941002
# 18           서경대학교  37.615095  127.013111
# 19       서울과학기술대학교  37.631668  127.077481
# 20         서울교육대학교  37.489961  127.016412
# ...

# %%
pd.read_excel("./data/서울지역 대학교 위치.xlsx")
df[:2]
# Out:
#             대학교         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797

# %%
# !pip install folium
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import folium
# Out:
# C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
li1 = [1, 2, 3]
li2 = ["A", "B", "C"]

# %%
li = []
for i in range(3):
    li.append( (li1[i], li2[i]) )

li
# Out:
# [(1, 'A'), (2, 'B'), (3, 'C')]

# %%
list(zip(li1, li2))
# Out:
# [(1, 'A'), (2, 'B'), (3, 'C')]

# %%
# list(zip(df['대학교'], df['위도'], df['경도'] ))

for name, lat, long in zip(df['대학교'], df['위도'], df['경도'] ):
    print(name, lat, long)
# Out:
# KAIST 서울캠퍼스  37.592573 127.046737
# KC대학교 37.5483449 126.8547974
# 가톨릭대학교(성신교정) 37.5859218 127.0043275
# 가톨릭대학교(성의교정) 37.4996227 127.0060653
# 감리교신학대학교 37.5676455 126.96161
# 건국대학교 37.5407625 127.0793428
# 경기대학교 서울캠퍼스  37.300485 127.035833
# 경희대학교 서울캠퍼스  37.5961951 127.052544
# 고려대학교 33.8477818 -117.9777482
# 광운대학교 37.6194965 127.0596958
# 국민대학교 37.6096409 126.997697
# 덕성여자대학교 37.6511988 127.0161604
# 동국대학교 37.5574771 127.0020518
# 동덕여자대학교 37.6063202 127.041808
# 명지대학교 서울캠퍼스  37.5802046 126.9234451
# 삼육대학교 37.6429515 127.1054757
# 상명대학교 서울캠퍼스  37.602638 126.955252
# 서강대학교 37.5509442 126.9410023
# 서경대학교 37.615095 127.0131113
# 서울과학기술대학교 37.6316684 127.0774813
# 서울교육대학교 37.4899615 127.0164124
# 서울기독대학교 37.6009228 126.9123818
# 서울대학교 37.459882 126.9519053
# 서울시립대학교 37.5838657 127.0587771
# 서울여자대학교 37.6281126 127.0904568
# 서울한영대학교 37.4965411 126.8512616
# 성공회대학교 37.4872325 126.8253202
# 성균관대학교 서울캠퍼스   37.588227 126.993606
# 성신여자대학교 37.5913103 127.0221312
# 세종대학교 37.5502596 127.073139
# ...

# %%
seoul_map = folium.Map([37.592573, 127.046737], zoom_start=12)

# [위도 , 경도]

# %%
for name, lat, long in zip(df['대학교'], df['위도'], df['경도'] ):
    folium.Marker([lat, long], tooltip = name).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
for name, lat, long in zip(df['대학교'], df['위도'], df['경도'] ):
    folium.CircleMarker([lat, long], radius = 5, color = 'white', 
                        fill = True, fill_color = 'Red', fill_opacity = 0.8).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# # 마무리 QA 과제

# %% [markdown]
# ## 3월 26일

# %%
# Q1. shopping list DataFrame 만들기

import pandas as pd

shopping_list = pd.DataFrame({
    "category": ['food', 'drinks', 'clothes'],
    "price": [30000, 4500, 25000],
    "ea": [5, 2, 1]}, index = ['파이', '콜라', '양말'])

print(shopping_list)
# Out:
#    category  price  ea
# 파이     food  30000   5
# 콜라   drinks   4500   2
# 양말  clothes  25000   1

# %%
# Q2. 짝수 열만 출력하기

shopping_list.iloc[:, 0::2]
# Out:
#    category  ea
# 파이     food   5
# 콜라   drinks   2
# 양말  clothes   1

# %%
# Q3. 파이 행 만 출력하기

shopping_list.iloc[0:1, 0:]
# Out:
#    category  price  ea
# 파이     food  30000   5

# %% [markdown]
# ## 3월 27일
